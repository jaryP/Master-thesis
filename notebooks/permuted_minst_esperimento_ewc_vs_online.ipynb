# %%
import sys
import os
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from networks import NoKafnet, Kafnet
import utils.datasetsUtils.MINST as MINST
from utils.datasetsUtils.taskManager import SingleTargetClassificationTask, NoTask
import configs.configClasses as configClasses
from torchvision.transforms import transforms
import torch
from Trainer import Trainer
import matplotlib.pyplot as plt
from collections import defaultdict
import copy
import numpy as np

# %%
print(torch.cuda.is_available())
print(torch.cuda.device_count())
print(torch.cuda.get_device_name(torch.cuda.current_device()))
# Out:
# True
# 1
# GeForce GTX 1050

# %%
config = configClasses.RealEwc()
config.EPOCHS = 20
config.L1_REG = 0
config.IS_CONVOLUTIONAL = False
print(config)

configOnline = configClasses.OnlineLearningConfig()
configOnline.EPOCHS = 20
configOnline.L1_REG = 0
configOnline.IS_CONVOLUTIONAL = False

print(configOnline)
# Out:
# CONFIG PARAMETERS
# BATCH_SIZE: 64
# DEVICE: cuda
# EPOCHS: 20
# EWC_IMPORTANCE: 1000
# EWC_SAMPLE_SIZE: 250
# EWC_TYPE: <class 'networks.continual_learning.RealEWC'>
# IS_CONVOLUTIONAL: False
# ITERS: 1
# L1_REG: 0
# LOSS: cross_entropy
# LR: 0.001
# MODEL_NAME:
# OPTIMIZER: SGD
# RUN_NAME: default
# USE_EWC: True
# USE_TENSORBOARD: True
#
# CONFIG PARAMETERS
# BATCH_SIZE: 64
# DEVICE: cuda
# EPOCHS: 20
# EWC_IMPORTANCE: 1000
# EWC_SAMPLE_SIZE: 250
# EWC_TYPE: <class 'networks.continual_learning.OnlineEWC'>
# GAMMA: 1.0
# IS_CONVOLUTIONAL: False
# ITERS: 1
# L1_REG: 0
# LOSS: cross_entropy
# LR: 0.001
# MODEL_NAME:
# OPTIMIZER: SGD
# RUN_NAME: default
# USE_EWC: True
# USE_TENSORBOARD: True

# %%
dataset = MINST.PermutedMINST('../data/minst', download=True, n_permutation=3,
                        force_download=False, train_split=0.8, transform=None, target_transform=None)
dataset.load_dataset()

dataset_no_ewt = copy.deepcopy(dataset)
# Out:
# ../data/minst/download
# task #0 with train 56000 and test 14000 images (label: 0)
# task #1 with train 56000 and test 14000 images (label: 1)
# task #2 with train 56000 and test 14000 images (label: 2)

# %%
net_ewt = NoKafnet.MLP(len(dataset.class_to_idx))
net_no_ewt = copy.deepcopy(net_ewt)

print('Numero di parametri rete classica: ', sum([torch.numel(p) for p in net_ewt.parameters()]))
# Out:
# Numero di parametri rete classica:  638810

# %%
trainer_ewt = Trainer(net_ewt, dataset, config)
trainer_no_ewt = Trainer(net_no_ewt, dataset_no_ewt, configOnline)

# %%
results_ewt, metrics_ewt = trainer_ewt.all_tasks()
# Out:
# Training task (ewc) 0, epoch 1: 100%|██████████| 875/875 [00:04<00:00, 187.82it/s, loss=2.3, batch#=875]
# Testing task 0: 219it [00:00, 227.95it/s, batch#=219]
# Training task (ewc) 0, epoch 2: 100%|██████████| 875/875 [00:04<00:00, 196.40it/s, loss=2.29, batch#=875]
# Testing task 0: 219it [00:00, 230.49it/s, batch#=219]
# Training task (ewc) 0, epoch 3: 100%|██████████| 875/875 [00:04<00:00, 187.78it/s, loss=2.28, batch#=875]
# Testing task 0: 219it [00:00, 242.40it/s, batch#=219]
# Training task (ewc) 0, epoch 4: 100%|██████████| 875/875 [00:04<00:00, 195.46it/s, loss=2.27, batch#=875]
# Testing task 0: 219it [00:00, 236.22it/s, batch#=219]
# Training task (ewc) 0, epoch 5: 100%|██████████| 875/875 [00:04<00:00, 194.59it/s, loss=2.26, batch#=875]
# Testing task 0: 219it [00:00, 229.14it/s, batch#=219]
# Training task (ewc) 0, epoch 6: 100%|██████████| 875/875 [00:04<00:00, 194.55it/s, loss=2.23, batch#=875]
# Testing task 0: 219it [00:00, 222.84it/s, batch#=219]
# Training task (ewc) 0, epoch 7: 100%|██████████| 875/875 [00:04<00:00, 194.69it/s, loss=2.2, batch#=875]
# Testing task 0: 219it [00:00, 234.32it/s, batch#=219]
# Training task (ewc) 0, epoch 8: 100%|██████████| 875/875 [00:04<00:00, 193.41it/s, loss=2.14, batch#=875]
# Testing task 0: 219it [00:00, 234.17it/s, batch#=219]
# Training task (ewc) 0, epoch 9: 100%|██████████| 875/875 [00:04<00:00, 195.68it/s, loss=2.04, batch#=875]
# Testing task 0: 219it [00:00, 233.23it/s, batch#=219]
# Training task (ewc) 0, epoch 10: 100%|██████████| 875/875 [00:04<00:00, 195.37it/s, loss=1.88, batch#=875]
# Testing task 0: 219it [00:00, 234.05it/s, batch#=219]
# Training task (ewc) 0, epoch 11: 100%|██████████| 875/875 [00:04<00:00, 193.78it/s, loss=1.64, batch#=875]
# Testing task 0: 219it [00:00, 230.77it/s, batch#=219]
# Training task (ewc) 0, epoch 12: 100%|██████████| 875/875 [00:04<00:00, 196.58it/s, loss=1.35, batch#=875]
# Testing task 0: 219it [00:00, 242.53it/s, batch#=219]
# Training task (ewc) 0, epoch 13: 100%|██████████| 875/875 [00:04<00:00, 196.19it/s, loss=1.09, batch#=875]
# Testing task 0: 219it [00:00, 240.21it/s, batch#=219]
# Training task (ewc) 0, epoch 14: 100%|██████████| 875/875 [00:04<00:00, 195.60it/s, loss=0.904, batch#=875]
# Testing task 0: 219it [00:00, 234.68it/s, batch#=219]
# Training task (ewc) 0, epoch 15: 100%|██████████| 875/875 [00:04<00:00, 197.02it/s, loss=0.775, batch#=875]
# Testing task 0: 219it [00:00, 239.92it/s, batch#=219]
# Training task (ewc) 0, epoch 16: 100%|██████████| 875/875 [00:04<00:00, 199.67it/s, loss=0.688, batch#=875]
# Testing task 0: 219it [00:00, 235.76it/s, batch#=219]
# Training task (ewc) 0, epoch 17: 100%|██████████| 875/875 [00:04<00:00, 191.81it/s, loss=0.627, batch#=875]
# Testing task 0: 219it [00:00, 239.09it/s, batch#=219]
# Training task (ewc) 0, epoch 18: 100%|██████████| 875/875 [00:04<00:00, 199.82it/s, loss=0.583, batch#=875]
# Testing task 0: 219it [00:00, 233.30it/s, batch#=219]
# Training task (ewc) 0, epoch 19: 100%|██████████| 875/875 [00:04<00:00, 196.37it/s, loss=0.549, batch#=875]
# Testing task 0: 219it [00:00, 241.24it/s, batch#=219]
# Training task (ewc) 0, epoch 20: 100%|██████████| 875/875 [00:04<00:00, 197.02it/s, loss=0.523, batch#=875]
# Testing task 0: 219it [00:00, 234.79it/s, batch#=219]
# Testing task 1: 219it [00:00, 241.15it/s, batch#=219]
# Testing task 2: 219it [00:00, 243.01it/s, batch#=219]
# Training task (ewc) 1, epoch 1: 100%|██████████| 875/875 [00:05<00:00, 147.96it/s, loss=1.43, batch#=875]
# Testing task 1: 219it [00:00, 237.67it/s, batch#=219]
# Testing task 0: 219it [00:00, 242.47it/s, batch#=219]
# Training task (ewc) 1, epoch 2: 100%|██████████| 875/875 [00:05<00:00, 148.25it/s, loss=0.97, batch#=875]
# Testing task 1: 219it [00:00, 238.69it/s, batch#=219]
# Testing task 0: 219it [00:00, 234.52it/s, batch#=219]
# Training task (ewc) 1, epoch 3: 100%|██████████| 875/875 [00:05<00:00, 147.35it/s, loss=0.848, batch#=875]
# Testing task 1: 219it [00:00, 240.72it/s, batch#=219]
# Testing task 0: 219it [00:00, 242.73it/s, batch#=219]
# Training task (ewc) 1, epoch 4: 100%|██████████| 875/875 [00:05<00:00, 147.30it/s, loss=0.782, batch#=875]
# Testing task 1: 219it [00:00, 235.83it/s, batch#=219]
# Testing task 0: 219it [00:00, 239.80it/s, batch#=219]
# Training task (ewc) 1, epoch 5: 100%|██████████| 875/875 [00:05<00:00, 147.61it/s, loss=0.739, batch#=875]
# Testing task 1: 219it [00:00, 234.25it/s, batch#=219]
# Testing task 0: 219it [00:00, 236.75it/s, batch#=219]
# Training task (ewc) 1, epoch 6: 100%|██████████| 875/875 [00:06<00:00, 140.47it/s, loss=0.707, batch#=875]
# Testing task 1: 219it [00:00, 235.16it/s, batch#=219]
# Testing task 0: 219it [00:00, 231.65it/s, batch#=219]
# Training task (ewc) 1, epoch 7: 100%|██████████| 875/875 [00:06<00:00, 144.61it/s, loss=0.682, batch#=875]
# Testing task 1: 219it [00:00, 223.59it/s, batch#=219]
# Testing task 0: 219it [00:00, 223.26it/s, batch#=219]
# Training task (ewc) 1, epoch 8: 100%|██████████| 875/875 [00:06<00:00, 145.14it/s, loss=0.662, batch#=875]
# Testing task 1: 219it [00:00, 237.67it/s, batch#=219]
# Testing task 0: 219it [00:01, 211.55it/s, batch#=219]
# Training task (ewc) 1, epoch 9: 100%|██████████| 875/875 [00:06<00:00, 142.88it/s, loss=0.645, batch#=875]
# Testing task 1: 219it [00:00, 239.42it/s, batch#=219]
# Testing task 0: 219it [00:00, 226.23it/s, batch#=219]
# Training task (ewc) 1, epoch 10: 100%|██████████| 875/875 [00:06<00:00, 143.97it/s, loss=0.63, batch#=875]
# Testing task 1: 219it [00:00, 229.06it/s, batch#=219]
# Testing task 0: 219it [00:00, 232.31it/s, batch#=219]
# Training task (ewc) 1, epoch 11: 100%|██████████| 875/875 [00:06<00:00, 145.55it/s, loss=0.617, batch#=875]
# Testing task 1: 219it [00:00, 234.62it/s, batch#=219]
# Testing task 0: 219it [00:00, 238.75it/s, batch#=219]
# Training task (ewc) 1, epoch 12: 100%|██████████| 875/875 [00:05<00:00, 148.90it/s, loss=0.606, batch#=875]
# Testing task 1: 219it [00:00, 225.59it/s, batch#=219]
# Testing task 0: 219it [00:00, 231.21it/s, batch#=219]
# Training task (ewc) 1, epoch 13: 100%|██████████| 875/875 [00:05<00:00, 146.12it/s, loss=0.596, batch#=875]
# Testing task 1: 219it [00:00, 239.93it/s, batch#=219]
# Testing task 0: 219it [00:00, 238.78it/s, batch#=219]
# Training task (ewc) 1, epoch 14: 100%|██████████| 875/875 [00:05<00:00, 147.42it/s, loss=0.586, batch#=875]
# Testing task 1: 219it [00:00, 239.56it/s, batch#=219]
# Testing task 0: 219it [00:00, 239.51it/s, batch#=219]
# Training task (ewc) 1, epoch 15: 100%|██████████| 875/875 [00:05<00:00, 146.07it/s, loss=0.578, batch#=875]
# Testing task 1: 219it [00:00, 232.87it/s, batch#=219]
# Testing task 0: 219it [00:00, 241.76it/s, batch#=219]
# Training task (ewc) 1, epoch 16: 100%|██████████| 875/875 [00:05<00:00, 146.46it/s, loss=0.57, batch#=875]
# Testing task 1: 219it [00:00, 230.21it/s, batch#=219]
# Testing task 0: 219it [00:00, 225.71it/s, batch#=219]
# Training task (ewc) 1, epoch 17: 100%|██████████| 875/875 [00:05<00:00, 147.00it/s, loss=0.563, batch#=875]
# Testing task 1: 219it [00:00, 233.48it/s, batch#=219]
# Testing task 0: 219it [00:00, 237.14it/s, batch#=219]
# Training task (ewc) 1, epoch 18: 100%|██████████| 875/875 [00:05<00:00, 146.18it/s, loss=0.556, batch#=875]
# Testing task 1: 219it [00:00, 234.23it/s, batch#=219]
# Testing task 0: 219it [00:00, 237.30it/s, batch#=219]
# Training task (ewc) 1, epoch 19: 100%|██████████| 875/875 [00:05<00:00, 147.74it/s, loss=0.549, batch#=875]
# Testing task 1: 219it [00:00, 234.14it/s, batch#=219]
# Testing task 0: 219it [00:00, 237.36it/s, batch#=219]
# Training task (ewc) 1, epoch 20: 100%|██████████| 875/875 [00:05<00:00, 146.54it/s, loss=0.543, batch#=875]
# Testing task 1: 219it [00:00, 237.89it/s, batch#=219]
# Testing task 0: 219it [00:00, 238.86it/s, batch#=219]
# Testing task 2: 219it [00:00, 234.65it/s, batch#=219]
# Training task (ewc) 2, epoch 1: 100%|██████████| 875/875 [00:07<00:00, 120.92it/s, loss=2.73, batch#=875]
# Testing task 2: 219it [00:00, 247.93it/s, batch#=219]
# Testing task 0: 219it [00:00, 242.15it/s, batch#=219]
# Testing task 1: 219it [00:00, 242.66it/s, batch#=219]
# Training task (ewc) 2, epoch 2: 100%|██████████| 875/875 [00:07<00:00, 118.24it/s, loss=2.04, batch#=875]
# Testing task 2: 219it [00:00, 228.97it/s, batch#=219]
# Testing task 0: 219it [00:01, 218.39it/s, batch#=219]
# Testing task 1: 219it [00:01, 207.19it/s, batch#=219]
# Training task (ewc) 2, epoch 3: 100%|██████████| 875/875 [00:07<00:00, 114.81it/s, loss=1.9, batch#=875]
# Testing task 2: 219it [00:00, 242.38it/s, batch#=219]
# Testing task 0: 219it [00:00, 240.04it/s, batch#=219]
# Testing task 1: 219it [00:00, 234.91it/s, batch#=219]
# Training task (ewc) 2, epoch 4: 100%|██████████| 875/875 [00:07<00:00, 122.08it/s, loss=1.82, batch#=875]
# Testing task 2: 219it [00:00, 235.62it/s, batch#=219]
# Testing task 0: 219it [00:00, 231.15it/s, batch#=219]
# Testing task 1: 219it [00:00, 235.74it/s, batch#=219]
# Training task (ewc) 2, epoch 5: 100%|██████████| 875/875 [00:07<00:00, 124.62it/s, loss=1.78, batch#=875]
# Testing task 2: 219it [00:00, 240.19it/s, batch#=219]
# Testing task 0: 219it [00:00, 241.25it/s, batch#=219]
# Testing task 1: 219it [00:00, 242.52it/s, batch#=219]
# Training task (ewc) 2, epoch 6: 100%|██████████| 875/875 [00:07<00:00, 121.21it/s, loss=1.74, batch#=875]
# Testing task 2: 219it [00:00, 239.85it/s, batch#=219]
# Testing task 0: 219it [00:00, 236.41it/s, batch#=219]
# Testing task 1: 219it [00:00, 229.67it/s, batch#=219]
# Training task (ewc) 2, epoch 7: 100%|██████████| 875/875 [00:07<00:00, 122.37it/s, loss=1.72, batch#=875]
# Testing task 2: 219it [00:00, 240.83it/s, batch#=219]
# Testing task 0: 219it [00:00, 244.55it/s, batch#=219]
# Testing task 1: 219it [00:00, 244.66it/s, batch#=219]
# Training task (ewc) 2, epoch 8: 100%|██████████| 875/875 [00:07<00:00, 122.81it/s, loss=1.69, batch#=875]
# Testing task 2: 219it [00:00, 228.04it/s, batch#=219]
# Testing task 0: 219it [00:00, 239.51it/s, batch#=219]
# Testing task 1: 219it [00:00, 237.22it/s, batch#=219]
# Training task (ewc) 2, epoch 9: 100%|██████████| 875/875 [00:07<00:00, 121.31it/s, loss=1.68, batch#=875]
# Testing task 2: 219it [00:00, 239.82it/s, batch#=219]
# Testing task 0: 219it [00:00, 238.97it/s, batch#=219]
# Testing task 1: 219it [00:00, 234.42it/s, batch#=219]
# Training task (ewc) 2, epoch 10: 100%|██████████| 875/875 [00:07<00:00, 122.89it/s, loss=1.66, batch#=875]
# Testing task 2: 219it [00:00, 237.59it/s, batch#=219]
# Testing task 0: 219it [00:00, 235.48it/s, batch#=219]
# Testing task 1: 219it [00:00, 242.56it/s, batch#=219]
# Training task (ewc) 2, epoch 11: 100%|██████████| 875/875 [00:07<00:00, 121.57it/s, loss=1.65, batch#=875]
# Testing task 2: 219it [00:00, 237.02it/s, batch#=219]
# Testing task 0: 219it [00:00, 240.27it/s, batch#=219]
# Testing task 1: 219it [00:00, 242.12it/s, batch#=219]
# Training task (ewc) 2, epoch 12: 100%|██████████| 875/875 [00:07<00:00, 121.93it/s, loss=1.63, batch#=875]
# Testing task 2: 219it [00:00, 236.28it/s, batch#=219]
# Testing task 0: 219it [00:00, 231.99it/s, batch#=219]
# Testing task 1: 219it [00:00, 239.18it/s, batch#=219]
# Training task (ewc) 2, epoch 13: 100%|██████████| 875/875 [00:07<00:00, 121.85it/s, loss=1.62, batch#=875]
# Testing task 2: 219it [00:00, 243.64it/s, batch#=219]
# Testing task 0: 219it [00:00, 239.74it/s, batch#=219]
# Testing task 1: 219it [00:00, 242.19it/s, batch#=219]
# Training task (ewc) 2, epoch 14: 100%|██████████| 875/875 [00:07<00:00, 121.81it/s, loss=1.61, batch#=875]
# Testing task 2: 219it [00:00, 236.46it/s, batch#=219]
# Testing task 0: 219it [00:00, 240.56it/s, batch#=219]
# Testing task 1: 219it [00:00, 235.25it/s, batch#=219]
# Training task (ewc) 2, epoch 15: 100%|██████████| 875/875 [00:07<00:00, 120.92it/s, loss=1.6, batch#=875]
# Testing task 2: 219it [00:00, 242.59it/s, batch#=219]
# Testing task 0: 219it [00:00, 244.76it/s, batch#=219]
# Testing task 1: 219it [00:00, 245.36it/s, batch#=219]
# Training task (ewc) 2, epoch 16: 100%|██████████| 875/875 [00:07<00:00, 123.70it/s, loss=1.59, batch#=875]
# Testing task 2: 219it [00:00, 231.15it/s, batch#=219]
# Testing task 0: 219it [00:00, 242.39it/s, batch#=219]
# Testing task 1: 219it [00:00, 243.24it/s, batch#=219]
# Training task (ewc) 2, epoch 17: 100%|██████████| 875/875 [00:07<00:00, 120.69it/s, loss=1.59, batch#=875]
# Testing task 2: 219it [00:00, 244.65it/s, batch#=219]
# Testing task 0: 219it [00:00, 243.66it/s, batch#=219]
# Testing task 1: 219it [00:00, 243.52it/s, batch#=219]
# Training task (ewc) 2, epoch 18: 100%|██████████| 875/875 [00:07<00:00, 122.72it/s, loss=1.58, batch#=875]
# Testing task 2: 219it [00:00, 235.57it/s, batch#=219]
# Testing task 0: 219it [00:00, 233.75it/s, batch#=219]
# Testing task 1: 219it [00:00, 237.85it/s, batch#=219]
# Training task (ewc) 2, epoch 19: 100%|██████████| 875/875 [00:07<00:00, 122.14it/s, loss=1.57, batch#=875]
# Testing task 2: 219it [00:00, 219.37it/s, batch#=219]
# Testing task 0: 219it [00:01, 203.97it/s, batch#=219]
# Testing task 1: 219it [00:01, 218.74it/s, batch#=219]
# Training task (ewc) 2, epoch 20: 100%|██████████| 875/875 [00:07<00:00, 119.85it/s, loss=1.57, batch#=875]
# Testing task 2: 219it [00:00, 232.07it/s, batch#=219]
# Testing task 0: 219it [00:00, 233.19it/s, batch#=219]
# Testing task 1: 219it [00:00, 232.66it/s, batch#=219]
# /media/jary/DATA/Uni/tesi/master-thesis-master/utils/datasetsUtils/dataset.py:53: UserWarning: No more tasks...
#   warnings.warn("No more tasks...")

# %%
results_no_ewt, metrics_no_ewt = trainer_no_ewt.all_tasks()
# Out:
# Training task (ewc) 0, epoch 1: 100%|██████████| 875/875 [00:04<00:00, 193.31it/s, loss=2.3, batch#=875]
# Testing task 0: 219it [00:00, 228.38it/s, batch#=219]
# Training task (ewc) 0, epoch 2: 100%|██████████| 875/875 [00:04<00:00, 196.14it/s, loss=2.29, batch#=875]
# Testing task 0: 219it [00:00, 240.36it/s, batch#=219]
# Training task (ewc) 0, epoch 3: 100%|██████████| 875/875 [00:04<00:00, 195.54it/s, loss=2.28, batch#=875]
# Testing task 0: 219it [00:00, 232.10it/s, batch#=219]
# Training task (ewc) 0, epoch 4: 100%|██████████| 875/875 [00:04<00:00, 191.93it/s, loss=2.27, batch#=875]
# Testing task 0: 219it [00:00, 240.68it/s, batch#=219]
# Training task (ewc) 0, epoch 5: 100%|██████████| 875/875 [00:04<00:00, 196.13it/s, loss=2.26, batch#=875]
# Testing task 0: 219it [00:00, 239.34it/s, batch#=219]
# Training task (ewc) 0, epoch 6: 100%|██████████| 875/875 [00:04<00:00, 191.62it/s, loss=2.23, batch#=875]
# Testing task 0: 219it [00:01, 208.37it/s, batch#=219]
# Training task (ewc) 0, epoch 7: 100%|██████████| 875/875 [00:04<00:00, 194.30it/s, loss=2.2, batch#=875]
# Testing task 0: 219it [00:00, 223.77it/s, batch#=219]
# Training task (ewc) 0, epoch 8: 100%|██████████| 875/875 [00:04<00:00, 193.89it/s, loss=2.14, batch#=875]
# Testing task 0: 219it [00:00, 228.30it/s, batch#=219]
# Training task (ewc) 0, epoch 9: 100%|██████████| 875/875 [00:04<00:00, 197.48it/s, loss=2.04, batch#=875]
# Testing task 0: 219it [00:00, 235.39it/s, batch#=219]
# Training task (ewc) 0, epoch 10: 100%|██████████| 875/875 [00:04<00:00, 195.12it/s, loss=1.88, batch#=875]
# Testing task 0: 219it [00:00, 232.48it/s, batch#=219]
# Training task (ewc) 0, epoch 11: 100%|██████████| 875/875 [00:04<00:00, 194.18it/s, loss=1.64, batch#=875]
# Testing task 0: 219it [00:00, 236.58it/s, batch#=219]
# Training task (ewc) 0, epoch 12: 100%|██████████| 875/875 [00:04<00:00, 201.08it/s, loss=1.35, batch#=875]
# Testing task 0: 219it [00:00, 238.78it/s, batch#=219]
# Training task (ewc) 0, epoch 13: 100%|██████████| 875/875 [00:04<00:00, 196.28it/s, loss=1.09, batch#=875]
# Testing task 0: 219it [00:00, 237.08it/s, batch#=219]
# Training task (ewc) 0, epoch 14: 100%|██████████| 875/875 [00:04<00:00, 195.48it/s, loss=0.904, batch#=875]
# Testing task 0: 219it [00:00, 234.97it/s, batch#=219]
# Training task (ewc) 0, epoch 15: 100%|██████████| 875/875 [00:04<00:00, 197.53it/s, loss=0.775, batch#=875]
# Testing task 0: 219it [00:00, 236.18it/s, batch#=219]
# Training task (ewc) 0, epoch 16: 100%|██████████| 875/875 [00:04<00:00, 197.52it/s, loss=0.688, batch#=875]
# Testing task 0: 219it [00:00, 240.73it/s, batch#=219]
# Training task (ewc) 0, epoch 17: 100%|██████████| 875/875 [00:04<00:00, 185.93it/s, loss=0.627, batch#=875]
# Testing task 0: 219it [00:01, 205.33it/s, batch#=219]
# Training task (ewc) 0, epoch 18: 100%|██████████| 875/875 [00:04<00:00, 186.00it/s, loss=0.583, batch#=875]
# Testing task 0: 219it [00:00, 233.29it/s, batch#=219]
# Training task (ewc) 0, epoch 19: 100%|██████████| 875/875 [00:04<00:00, 193.98it/s, loss=0.549, batch#=875]
# Testing task 0: 219it [00:00, 233.30it/s, batch#=219]
# Training task (ewc) 0, epoch 20: 100%|██████████| 875/875 [00:04<00:00, 194.36it/s, loss=0.523, batch#=875]
# Testing task 0: 219it [00:00, 235.92it/s, batch#=219]
# Testing task 1: 219it [00:00, 230.70it/s, batch#=219]
# Testing task 2: 219it [00:00, 235.11it/s, batch#=219]
# Training task (ewc) 1, epoch 1: 100%|██████████| 875/875 [00:05<00:00, 146.72it/s, loss=1.43, batch#=875]
# Testing task 1: 219it [00:00, 227.25it/s, batch#=219]
# Testing task 0: 219it [00:00, 232.31it/s, batch#=219]
# Training task (ewc) 1, epoch 2: 100%|██████████| 875/875 [00:05<00:00, 146.44it/s, loss=0.971, batch#=875]
# Testing task 1: 219it [00:00, 231.10it/s, batch#=219]
# Testing task 0: 219it [00:00, 238.73it/s, batch#=219]
# Training task (ewc) 1, epoch 3: 100%|██████████| 875/875 [00:06<00:00, 136.83it/s, loss=0.85, batch#=875]
# Testing task 1: 219it [00:00, 234.06it/s, batch#=219]
# Testing task 0: 219it [00:00, 237.46it/s, batch#=219]
# Training task (ewc) 1, epoch 4: 100%|██████████| 875/875 [00:05<00:00, 146.76it/s, loss=0.785, batch#=875]
# Testing task 1: 219it [00:00, 234.73it/s, batch#=219]
# Testing task 0: 219it [00:00, 235.88it/s, batch#=219]
# Training task (ewc) 1, epoch 5: 100%|██████████| 875/875 [00:05<00:00, 147.21it/s, loss=0.742, batch#=875]
# Testing task 1: 219it [00:00, 236.14it/s, batch#=219]
# Testing task 0: 219it [00:00, 241.24it/s, batch#=219]
# Training task (ewc) 1, epoch 6: 100%|██████████| 875/875 [00:05<00:00, 146.83it/s, loss=0.711, batch#=875]
# Testing task 1: 219it [00:00, 231.70it/s, batch#=219]
# Testing task 0: 219it [00:00, 239.88it/s, batch#=219]
# Training task (ewc) 1, epoch 7: 100%|██████████| 875/875 [00:05<00:00, 146.91it/s, loss=0.686, batch#=875]
# Testing task 1: 219it [00:00, 234.57it/s, batch#=219]
# Testing task 0: 219it [00:00, 228.02it/s, batch#=219]
# Training task (ewc) 1, epoch 8: 100%|██████████| 875/875 [00:05<00:00, 145.86it/s, loss=0.666, batch#=875]
# Testing task 1: 219it [00:00, 229.64it/s, batch#=219]
# Testing task 0: 219it [00:00, 236.54it/s, batch#=219]
# Training task (ewc) 1, epoch 9: 100%|██████████| 875/875 [00:05<00:00, 146.32it/s, loss=0.649, batch#=875]
# Testing task 1: 219it [00:00, 233.51it/s, batch#=219]
# Testing task 0: 219it [00:00, 236.29it/s, batch#=219]
# Training task (ewc) 1, epoch 10: 100%|██████████| 875/875 [00:05<00:00, 146.39it/s, loss=0.635, batch#=875]
# Testing task 1: 219it [00:00, 241.17it/s, batch#=219]
# Testing task 0: 219it [00:00, 243.63it/s, batch#=219]
# Training task (ewc) 1, epoch 11: 100%|██████████| 875/875 [00:05<00:00, 147.06it/s, loss=0.622, batch#=875]
# Testing task 1: 219it [00:00, 242.06it/s, batch#=219]
# Testing task 0: 219it [00:00, 235.84it/s, batch#=219]
# Training task (ewc) 1, epoch 12: 100%|██████████| 875/875 [00:05<00:00, 146.18it/s, loss=0.611, batch#=875]
# Testing task 1: 219it [00:00, 235.80it/s, batch#=219]
# Testing task 0: 219it [00:00, 239.81it/s, batch#=219]
# Training task (ewc) 1, epoch 13: 100%|██████████| 875/875 [00:05<00:00, 146.18it/s, loss=0.6, batch#=875]
# Testing task 1: 219it [00:00, 238.30it/s, batch#=219]
# Testing task 0: 219it [00:00, 239.32it/s, batch#=219]
# Training task (ewc) 1, epoch 14: 100%|██████████| 875/875 [00:06<00:00, 144.35it/s, loss=0.591, batch#=875]
# Testing task 1: 219it [00:00, 232.17it/s, batch#=219]
# Testing task 0: 219it [00:00, 239.83it/s, batch#=219]
# Training task (ewc) 1, epoch 15: 100%|██████████| 875/875 [00:06<00:00, 145.68it/s, loss=0.582, batch#=875]
# Testing task 1: 219it [00:00, 234.99it/s, batch#=219]
# Testing task 0: 219it [00:00, 242.03it/s, batch#=219]
# Training task (ewc) 1, epoch 16: 100%|██████████| 875/875 [00:06<00:00, 141.33it/s, loss=0.575, batch#=875]
# Testing task 1: 219it [00:00, 223.13it/s, batch#=219]
# Testing task 0: 219it [00:01, 212.44it/s, batch#=219]
# Training task (ewc) 1, epoch 17: 100%|██████████| 875/875 [00:06<00:00, 141.38it/s, loss=0.567, batch#=875]
# Testing task 1: 219it [00:00, 237.81it/s, batch#=219]
# Testing task 0: 219it [00:00, 233.45it/s, batch#=219]
# Training task (ewc) 1, epoch 18: 100%|██████████| 875/875 [00:06<00:00, 145.73it/s, loss=0.561, batch#=875]
# Testing task 1: 219it [00:00, 237.72it/s, batch#=219]
# Testing task 0: 219it [00:00, 234.57it/s, batch#=219]
# Training task (ewc) 1, epoch 19: 100%|██████████| 875/875 [00:06<00:00, 145.54it/s, loss=0.554, batch#=875]
# Testing task 1: 219it [00:00, 239.95it/s, batch#=219]
# Testing task 0: 219it [00:00, 240.34it/s, batch#=219]
# Training task (ewc) 1, epoch 20: 100%|██████████| 875/875 [00:05<00:00, 148.33it/s, loss=0.548, batch#=875]
# Testing task 1: 219it [00:00, 234.67it/s, batch#=219]
# Testing task 0: 219it [00:00, 237.36it/s, batch#=219]
# Testing task 2: 219it [00:00, 242.44it/s, batch#=219]
# Training task (ewc) 2, epoch 1: 100%|██████████| 875/875 [00:05<00:00, 146.71it/s, loss=1.41, batch#=875]
# Testing task 2: 219it [00:00, 239.34it/s, batch#=219]
# Testing task 0: 219it [00:00, 233.44it/s, batch#=219]
# Testing task 1: 219it [00:00, 236.17it/s, batch#=219]
# Training task (ewc) 2, epoch 2: 100%|██████████| 875/875 [00:05<00:00, 146.64it/s, loss=0.959, batch#=875]
# Testing task 2: 219it [00:00, 235.13it/s, batch#=219]
# Testing task 0: 219it [00:00, 239.44it/s, batch#=219]
# Testing task 1: 219it [00:00, 239.63it/s, batch#=219]
# Training task (ewc) 2, epoch 3: 100%|██████████| 875/875 [00:05<00:00, 147.71it/s, loss=0.859, batch#=875]
# Testing task 2: 219it [00:00, 229.65it/s, batch#=219]
# Testing task 0: 219it [00:00, 239.74it/s, batch#=219]
# Testing task 1: 219it [00:00, 243.78it/s, batch#=219]
# Training task (ewc) 2, epoch 4: 100%|██████████| 875/875 [00:05<00:00, 146.54it/s, loss=0.802, batch#=875]
# Testing task 2: 219it [00:00, 236.55it/s, batch#=219]
# Testing task 0: 219it [00:00, 232.68it/s, batch#=219]
# Testing task 1: 219it [00:00, 234.54it/s, batch#=219]
# Training task (ewc) 2, epoch 5: 100%|██████████| 875/875 [00:05<00:00, 147.73it/s, loss=0.764, batch#=875]
# Testing task 2: 219it [00:00, 237.75it/s, batch#=219]
# Testing task 0: 219it [00:00, 239.96it/s, batch#=219]
# Testing task 1: 219it [00:00, 235.00it/s, batch#=219]
# Training task (ewc) 2, epoch 6: 100%|██████████| 875/875 [00:05<00:00, 148.29it/s, loss=0.736, batch#=875]
# Testing task 2: 219it [00:00, 232.25it/s, batch#=219]
# Testing task 0: 219it [00:00, 242.25it/s, batch#=219]
# Testing task 1: 219it [00:00, 243.91it/s, batch#=219]
# Training task (ewc) 2, epoch 7: 100%|██████████| 875/875 [00:05<00:00, 147.84it/s, loss=0.713, batch#=875]
# Testing task 2: 219it [00:00, 242.11it/s, batch#=219]
# Testing task 0: 219it [00:00, 240.22it/s, batch#=219]
# Testing task 1: 219it [00:00, 237.63it/s, batch#=219]
# Training task (ewc) 2, epoch 8: 100%|██████████| 875/875 [00:05<00:00, 146.20it/s, loss=0.694, batch#=875]
# Testing task 2: 219it [00:00, 234.38it/s, batch#=219]
# Testing task 0: 219it [00:00, 235.09it/s, batch#=219]
# Testing task 1: 219it [00:00, 243.37it/s, batch#=219]
# Training task (ewc) 2, epoch 9: 100%|██████████| 875/875 [00:05<00:00, 148.45it/s, loss=0.679, batch#=875]
# Testing task 2: 219it [00:00, 233.07it/s, batch#=219]
# Testing task 0: 219it [00:00, 234.13it/s, batch#=219]
# Testing task 1: 219it [00:00, 245.98it/s, batch#=219]
# Training task (ewc) 2, epoch 10: 100%|██████████| 875/875 [00:05<00:00, 146.60it/s, loss=0.665, batch#=875]
# Testing task 2: 219it [00:00, 236.12it/s, batch#=219]
# Testing task 0: 219it [00:00, 239.66it/s, batch#=219]
# Testing task 1: 219it [00:00, 236.15it/s, batch#=219]
# Training task (ewc) 2, epoch 11: 100%|██████████| 875/875 [00:05<00:00, 146.75it/s, loss=0.653, batch#=875]
# Testing task 2: 219it [00:00, 234.07it/s, batch#=219]
# Testing task 0: 219it [00:00, 242.20it/s, batch#=219]
# Testing task 1: 219it [00:00, 240.89it/s, batch#=219]
# Training task (ewc) 2, epoch 12: 100%|██████████| 875/875 [00:05<00:00, 146.28it/s, loss=0.642, batch#=875]
# Testing task 2: 219it [00:00, 233.68it/s, batch#=219]
# Testing task 0: 219it [00:00, 235.21it/s, batch#=219]
# Testing task 1: 219it [00:00, 242.84it/s, batch#=219]
# Training task (ewc) 2, epoch 13: 100%|██████████| 875/875 [00:05<00:00, 147.12it/s, loss=0.633, batch#=875]
# Testing task 2: 219it [00:00, 229.72it/s, batch#=219]
# Testing task 0: 219it [00:00, 238.86it/s, batch#=219]
# Testing task 1: 219it [00:00, 236.72it/s, batch#=219]
# Training task (ewc) 2, epoch 14: 100%|██████████| 875/875 [00:05<00:00, 146.87it/s, loss=0.624, batch#=875]
# Testing task 2: 219it [00:00, 242.52it/s, batch#=219]
# Testing task 0: 219it [00:00, 238.83it/s, batch#=219]
# Testing task 1: 219it [00:00, 243.54it/s, batch#=219]
# Training task (ewc) 2, epoch 15: 100%|██████████| 875/875 [00:05<00:00, 147.35it/s, loss=0.616, batch#=875]
# Testing task 2: 219it [00:00, 233.77it/s, batch#=219]
# Testing task 0: 219it [00:00, 234.65it/s, batch#=219]
# Testing task 1: 219it [00:00, 234.75it/s, batch#=219]
# Training task (ewc) 2, epoch 16: 100%|██████████| 875/875 [00:06<00:00, 142.16it/s, loss=0.608, batch#=875]
# Testing task 2: 219it [00:00, 232.79it/s, batch#=219]
# Testing task 0: 219it [00:00, 240.19it/s, batch#=219]
# Testing task 1: 219it [00:00, 235.82it/s, batch#=219]
# Training task (ewc) 2, epoch 17: 100%|██████████| 875/875 [00:06<00:00, 145.01it/s, loss=0.602, batch#=875]
# Testing task 2: 219it [00:00, 241.11it/s, batch#=219]
# Testing task 0: 219it [00:00, 229.25it/s, batch#=219]
# Testing task 1: 219it [00:00, 233.74it/s, batch#=219]
# Training task (ewc) 2, epoch 18: 100%|██████████| 875/875 [00:06<00:00, 143.59it/s, loss=0.595, batch#=875]
# Testing task 2: 219it [00:00, 233.08it/s, batch#=219]
# Testing task 0: 219it [00:00, 239.29it/s, batch#=219]
# Testing task 1: 219it [00:00, 235.38it/s, batch#=219]
# Training task (ewc) 2, epoch 19: 100%|██████████| 875/875 [00:06<00:00, 145.67it/s, loss=0.589, batch#=875]
# Testing task 2: 219it [00:00, 235.45it/s, batch#=219]
# Testing task 0: 219it [00:00, 236.75it/s, batch#=219]
# Testing task 1: 219it [00:00, 234.75it/s, batch#=219]
# Training task (ewc) 2, epoch 20: 100%|██████████| 875/875 [00:06<00:00, 145.36it/s, loss=0.584, batch#=875]
# Testing task 2: 219it [00:00, 236.58it/s, batch#=219]
# Testing task 0: 219it [00:00, 227.35it/s, batch#=219]
# Testing task 1: 219it [00:00, 238.75it/s, batch#=219]

# %%
n_task = len(metrics_ewt['tasks'])
tot_epochs = 0

print('Online Ewc', metrics_no_ewt['metrics'])
print('Ewc', metrics_ewt['metrics'])


for k, v in metrics_no_ewt['tasks'].items():
    tot_epochs = max(tot_epochs, len(v['accuracy']))
             
for k, v in metrics_ewt['tasks'].items():
    tot_epochs = max(tot_epochs, len(v['accuracy']))
      
fig = plt.figure(figsize=(12, 24))

ax = None
for i, task in enumerate(metrics_ewt['tasks'].keys()):
        
    ewt = metrics_ewt['tasks'][task]
    no_ewt = metrics_no_ewt['tasks'][task]

    x = range(tot_epochs-len(ewt['accuracy']), tot_epochs)

    ax = fig.add_subplot(n_task, 1, i+1, sharex=ax) 
    
    ax.plot(x, ewt['accuracy'], label='ewt')
    ax.plot(x, no_ewt['accuracy'], label='online ewt')

    ax.set_xticks(range(0, tot_epochs, 5),minor=False)
    
    ax.set_title("Task {}".format(task))
    ax.legend(loc="lower left")
    ax.grid(True, axis='x')
    
fig.subplots_adjust(hspace=0.01)
# Out:
# Online Ewc {'fwt': 0.8651904761904762, 'bwt': -0.005071428571428578, 'remembering': 0.9949285714285714, 'pbwt': 0, 'accuracy': 0.5056785714285714}
# Ewc {'fwt': 0.8451904761904762, 'bwt': -0.02623809523809521, 'remembering': 0.9737619047619048, 'pbwt': 0, 'accuracy': 0.5053333333333333}
