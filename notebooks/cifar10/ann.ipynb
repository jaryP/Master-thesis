# %%
import sys
import os
module_path = os.path.abspath('/media/jary/DATA/Uni/tesi/codice')

if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from networks import NoKafnet, Kafnet
import utils.datasetsUtils.CIFAR as CIFAR
from utils.datasetsUtils.taskManager import IncrementalTaskClassification, NoTask
import configs.configClasses as configClasses
from torchvision.transforms import transforms
import torch
import matplotlib
import networks.continual_learning as continual_learning
import networks.continual_learning_beta as continual_learning_beta
from pylab import rcParams
from Trainer import Trainer
import matplotlib.pyplot as plt
from collections import defaultdict
from copy import deepcopy
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
from sklearn.decomposition import PCA
import brewer2mpl

# %%
torch.manual_seed(0)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
np.random.seed(0)

# %%
print(torch.cuda.is_available())
print(torch.cuda.device_count())
print(torch.cuda.get_device_name(torch.cuda.current_device()))
# Out:
# True
# 1
# GeForce GTX 1050

# %%
config = configClasses.DefaultConfig()
config.L1_REG = 0
config.EPOCHS = 10
config.SAVE_PATH = './models/ann'
config.IS_CONVOLUTIONAL = True
config.USE_CL = False
config.BATCH_SIZE = 32
config.MODEL_NAME = ''
config.NEXT_TASK_EPOCHS = None
config.NEXT_TASK_LR = None
config.OPTIMIZER = 'Adam'
print(config)
# Out:
# CONFIG PARAMETERS
# BATCH_SIZE: 32
# CL_PAR: {}
# CL_TEC: <class 'networks.continual_learning.EWC'>
# DEVICE: cuda
# EPOCHS: 10
# IS_CONVOLUTIONAL: True
# IS_INCREMENTAL: True
# ITERS: 1
# L1_REG: 0
# LOSS: cross_entropy
# LR: 0.001
# MODEL_NAME:
# NEXT_TASK_EPOCHS: None
# NEXT_TASK_LR: None
# OPTIMIZER: Adam
# RUN_NAME: default
# SAVE_PATH: ./models/ann
# USE_CL: False
# USE_TENSORBOARD: True

# %%
transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))]
)

dataset = CIFAR.Cifar10('../data/cifar10', download=True, transform=transform, 
                        task_manager=IncrementalTaskClassification(2),
                        force_download=False, train_split=0.8, target_transform=None)
dataset.load_dataset()
print(len(dataset.Y))
# Out:
# ../data/cifar10/download
# 60000

# %%
net = NoKafnet.synCNN(10)

# %%
experiments = [('no_cont_learning', None),
               ('ewc', continual_learning.OnlineEWC),
               ('gem', continual_learning.GEM_MEM),
               ('embedding', continual_learning.embedding)]

# %%
results = []
res = {}
EXPERIMENTS = 5

for i in range(EXPERIMENTS):
    for name, tec in experiments:        
        n = deepcopy(net)
        c = deepcopy(config)

        c.MODEL_NAME = name+'_'+str(i) 
        print(c.MODEL_NAME)

        if name == 'gem':
            c.CL_PAR = {'memorized_task_size': 100, 'sample_size': 50,'margin': 0.5}
            c.USE_CL = True
        elif name == 'ewc':
            c.CL_PAR = {'penalty_importance': 2e3, 'sample_size': 200}
            c.USE_CL = True
        elif name == 'embedding':
            c.CL_PAR = {'penalty_importance': 1, 'weights_type': 'distance', 
                        'sample_size': 30, 'distance': 'cosine','memorized_task_size': 100}
            c.USE_CL = True

        c.CL_TEC = tec
        trainer = Trainer(n, deepcopy(dataset), c, save_modality=2, verbose=False)

        r = trainer.load()
        if not r:
            r = trainer.all_tasks()
        print(r['metrics'])
        
        if name not in res:
            res[name] = [r]
        else:
            res[name].append(r)
        
        del trainer
        del n
# Out:
# no_cont_learning_0
# {'fwt': 0.401875, 'bwt': -0.33862499999999995, 'remembering': 0.661375, 'pbwt': 0, 'accuracy': 0.690888888888889}
# ewc_0
# {'fwt': 0.410375, 'bwt': -0.25079166666666663, 'remembering': 0.7492083333333334, 'pbwt': 0, 'accuracy': 0.6746666666666667}
# gem_0
# {'fwt': 0.4819583333333333, 'bwt': -0.10750000000000001, 'remembering': 0.8925, 'pbwt': 0, 'accuracy': 0.825}
# embedding_0
# {'fwt': 0.35183333333333333, 'bwt': -0.11958333333333333, 'remembering': 0.8804166666666666, 'pbwt': 0, 'accuracy': 0.8322499999999999}
# no_cont_learning_1
# {'fwt': 0.35783333333333334, 'bwt': -0.33725000000000005, 'remembering': 0.66275, 'pbwt': 0, 'accuracy': 0.6913333333333334}
# ewc_1
# {'fwt': 0.32025, 'bwt': -0.18762500000000001, 'remembering': 0.812375, 'pbwt': 0, 'accuracy': 0.6332777777777777}
# gem_1
# {'fwt': 0.40166666666666667, 'bwt': -0.12675, 'remembering': 0.87325, 'pbwt': 0, 'accuracy': 0.8059722222222222}
# embedding_1
# {'fwt': 0.24975, 'bwt': -0.14904166666666666, 'remembering': 0.8509583333333334, 'pbwt': 0, 'accuracy': 0.811888888888889}
# no_cont_learning_2
# {'fwt': 0.401875, 'bwt': -0.33862499999999995, 'remembering': 0.661375, 'pbwt': 0, 'accuracy': 0.690888888888889}
# ewc_2
# {'fwt': 0.394625, 'bwt': -0.2540833333333333, 'remembering': 0.7459166666666667, 'pbwt': 0, 'accuracy': 0.66825}
# gem_2
# {'fwt': 0.4527083333333334, 'bwt': -0.12258333333333331, 'remembering': 0.8774166666666667, 'pbwt': 0, 'accuracy': 0.8166111111111111}
# embedding_2
# {'fwt': 0.34587500000000004, 'bwt': -0.09824999999999998, 'remembering': 0.90175, 'pbwt': 0, 'accuracy': 0.8485}
# no_cont_learning_3
# {'fwt': 0.35783333333333334, 'bwt': -0.33725000000000005, 'remembering': 0.66275, 'pbwt': 0, 'accuracy': 0.6913333333333334}
# ewc_3
# {'fwt': 0.31929166666666664, 'bwt': -0.2311666666666667, 'remembering': 0.7688333333333333, 'pbwt': 0, 'accuracy': 0.6230833333333333}
# gem_3
# {'fwt': 0.35841666666666666, 'bwt': -0.11429166666666664, 'remembering': 0.8857083333333333, 'pbwt': 0, 'accuracy': 0.8137222222222221}
# embedding_3
# {'fwt': 0.25949999999999995, 'bwt': -0.14954166666666666, 'remembering': 0.8504583333333333, 'pbwt': 0, 'accuracy': 0.8146388888888888}
# no_cont_learning_4
# {'fwt': 0.4064583333333333, 'bwt': -0.37383333333333335, 'remembering': 0.6261666666666666, 'pbwt': 0, 'accuracy': 0.6648333333333334}
# ewc_4
# {'fwt': 0.44175000000000003, 'bwt': -0.14825, 'remembering': 0.85175, 'pbwt': 0, 'accuracy': 0.6755277777777777}
# gem_4
# {'fwt': 0.3454166666666667, 'bwt': -0.12025000000000001, 'remembering': 0.87975, 'pbwt': 0, 'accuracy': 0.8023611111111111}
# embedding_4
# {'fwt': 0.45512499999999995, 'bwt': -0.08066666666666665, 'remembering': 0.9193333333333333, 'pbwt': 0, 'accuracy': 0.857}

# %%
for k, v in res.items():
    r = {}
    metrics = {}
    acc = {}
    std = []
    
    EXP = len(v)

    for vv in v:
        if len(metrics) == 0:
            metrics = vv['metrics']
        else:
            for mk in vv['metrics'].keys():
                metrics[mk] += vv['metrics'][mk]

        if len(acc) == 0:
            acc = vv['tasks']
        else:
            for t in vv['tasks']:
                acc[t]['accuracy'] = [ac + vv['tasks'][t]['accuracy'][i] for i, ac in enumerate(acc[t]['accuracy'])]
        

        s = []
        for _, t in vv['tasks'].items():
            s.append(t['accuracy'])
        
        std.append(s)
            
    for i, v in metrics.items():
        metrics[i] = v / EXP
    
    for i, v in acc.items():
        p = [ i/EXP for i in acc[i]['accuracy']]
        acc[i]['accuracy'] = p
    
    rstd = {}
    
    std = list(zip(*std))
    for i in range(len(std)):
        t = np.asarray(std[i]).T
        rstd[str(i)] = list(np.std(t, 1))

    results.append((k, {'metrics': metrics, 'tasks': acc, 'std': rstd}))

# %%
print('RESULTS')
for name, r in results:
    print(name, r['metrics'])
    print()
# Out:
# RESULTS
# no_cont_learning {'fwt': 0.38517499999999993, 'bwt': -0.3451166666666666, 'remembering': 0.6548833333333334, 'pbwt': 0.0, 'accuracy': 0.6858555555555557}
#
# ewc {'fwt': 0.3772583333333333, 'bwt': -0.21438333333333331, 'remembering': 0.7856166666666666, 'pbwt': 0.0, 'accuracy': 0.654961111111111}
#
# gem {'fwt': 0.40803333333333336, 'bwt': -0.11827499999999999, 'remembering': 0.8817250000000001, 'pbwt': 0.0, 'accuracy': 0.8127333333333333}
#
# embedding {'fwt': 0.3324166666666667, 'bwt': -0.11941666666666666, 'remembering': 0.8805833333333333, 'pbwt': 0.0, 'accuracy': 0.8328555555555555}

# %%
params = {
   'axes.labelsize': 12,
   'font.family': 'Times New Roman',
   'font.size': 12,
   'legend.fontsize': 12,
   'xtick.labelsize': 12,
   'ytick.labelsize': 12,
   'text.usetex': False,
   'figure.figsize': [4, 3]
   }
rcParams.update(params)
matplotlib.rc('pdf', fonttype=42)

# brewer2mpl.get_map args: set name  set type  number of colors
bmap = brewer2mpl.get_map('Set2', 'qualitative', 8)

# %%
n_task = len(results[0][1]['tasks'])

tot_epochs = 0

for _, r in results:
    for k, v in r['tasks'].items():
        tot_epochs = max(tot_epochs, len(v['accuracy']))

figures = {}
colors = iter(bmap.mpl_colors)

for name, r in results:
    c = next(colors)
    for i, task in enumerate(r['tasks'].keys()):

        com = r['tasks'][task]

        x = range(tot_epochs-len(com['accuracy']), tot_epochs)
        acc = [0] * (tot_epochs-len(com['accuracy']))

        plt.figure(i, figsize=(22, 4))

        plt.axes().yaxis.set_tick_params(which='minor', right = 'off')
        plt.xticks(range(0, tot_epochs, 5))
        
        tr, = plt.plot(range(tot_epochs-len(com['accuracy'])), acc, color=c)
        plt.plot(x, com['accuracy'], label=name, color=c)
        tr.remove()
        plt.legend(loc="lower left")
        plt.grid(True, axis='both', color="0.9", linestyle='--', linewidth=1)
        
        plt.fill_between(x, np.asarray(com['accuracy'])-np.asarray(r['std'][str(task)]), 
                         np.asarray(com['accuracy'])+np.asarray(r['std'][str(task)]), alpha=0.2)
#         plt.errorbar(x, com['accuracy'], r['std'][str(task)], linestyle='None', marker='^')
        
        plt.legend(loc='lower left')
        
        plt.tight_layout()
        

for i in plt.get_fignums():
    plt.figure(i, figsize=(22, 4))
    plt.savefig('{}/cifar10_ann_task{}.pdf'.format(config.SAVE_PATH, i), bbox_inches='tight', pad_inches=0)
# Out:
# /home/jary/miniconda3/envs/tesi/lib/python3.6/site-packages/matplotlib/cbook/__init__.py:424: MatplotlibDeprecationWarning:
# Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warn_deprecated("2.2", "Passing one of 'on', 'true', 'off', 'false' as a "
# /home/jary/miniconda3/envs/tesi/lib/python3.6/site-packages/matplotlib/font_manager.py:1241: UserWarning: findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.
#   (prop.get_family(), self.defaultFamily[fontext]))
# /home/jary/miniconda3/envs/tesi/lib/python3.6/site-packages/matplotlib/figure.py:98: MatplotlibDeprecationWarning:
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   "Adding an axes using the same arguments as a previous axes "
