# %%
import sys
import os
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from networks import NoKafnet, Kafnet
import utils.datasetsUtils.MINST as MINST
from utils.datasetsUtils.taskManager import SingleTargetClassificationTask, NoTask
import configs.configClasses as configClasses
from torchvision.transforms import transforms
import torch
from Trainer import Trainer
import matplotlib.pyplot as plt
from collections import defaultdict
import copy
import numpy as np

# %%
print(torch.cuda.is_available())
print(torch.cuda.device_count())
print(torch.cuda.get_device_name(torch.cuda.current_device()))
# Out:
# True
# 1
# GeForce GTX 1050

# %%
config = configClasses.OnlineLearningConfig()
config.EPOCHS = 10
config.L1_REG = 0
#config.EWC_IMPORTANCE = 500
config.IS_CONVOLUTIONAL = False
print(config)

confing_no_ewt = copy.copy(config)
confing_no_ewt.USE_EWC = False
print(confing_no_ewt)
# Out:
# CONFIG PARAMETERS
# BATCH_SIZE: 64
# DEVICE: cuda
# EPOCHS: 10
# EWC_IMPORTANCE: 1000
# EWC_SAMPLE_SIZE: 250
# EWC_TYPE: <class 'networks.continual_learning.OnlineEWC'>
# GAMMA: 0.8
# IS_CONVOLUTIONAL: False
# ITERS: 1
# L1_REG: 0
# LOSS: cross_entropy
# LR: 0.001
# MODEL_NAME:
# OPTIMIZER: SGD
# RUN_NAME: default
# USE_EWC: True
# USE_TENSORBOARD: True
#
# CONFIG PARAMETERS
# BATCH_SIZE: 64
# DEVICE: cuda
# EPOCHS: 10
# EWC_IMPORTANCE: 1000
# EWC_SAMPLE_SIZE: 250
# EWC_TYPE: <class 'networks.continual_learning.OnlineEWC'>
# GAMMA: 0.8
# IS_CONVOLUTIONAL: False
# ITERS: 1
# L1_REG: 0
# LOSS: cross_entropy
# LR: 0.001
# MODEL_NAME:
# OPTIMIZER: SGD
# RUN_NAME: default
# USE_EWC: False
# USE_TENSORBOARD: True

# %%
dataset = MINST.PermutedMINST('../data/minst', download=True, n_permutation=2,
                        force_download=False, train_split=0.8, transform=None, target_transform=None)
dataset.load_dataset()

dataset_no_ewt = copy.deepcopy(dataset)
# Out:
# ../data/minst/download
# task #0 with train 56000 and test 14000 images (label: 0)
# task #1 with train 56000 and test 14000 images (label: 1)

# %%
net_ewt = NoKafnet.MLP(len(dataset.class_to_idx))
net_no_ewt = copy.deepcopy(net_ewt)

kaf_ewt = Kafnet.KAFMLP(len(dataset.class_to_idx))
kaf_no_ewt = Kafnet.KAFMLP(len(dataset.class_to_idx))

print('Numero di parametri rete classica: ', sum([torch.numel(p) for p in net_ewt.parameters()]))
print('Numero di parametri KAFNET: ', sum([torch.numel(p) for p in kaf_ewt.parameters()]))
# Out:
# Numero di parametri rete classica:  638810
# Numero di parametri KAFNET:  662810

# %%
trainer_kaf_ewt = Trainer(kaf_ewt, copy.deepcopy(dataset), config)
trainer_kaf_no_ewt = Trainer(kaf_no_ewt, copy.deepcopy(dataset), confing_no_ewt)

trainer_ewt = Trainer(net_ewt, dataset, config)
trainer_no_ewt = Trainer(net_no_ewt, dataset_no_ewt, confing_no_ewt)

# %%
results_kaf_ewt, metrics_kaf_ewt = trainer_kaf_ewt.all_tasks()
# Out:
# Training task (ewc) 0, epoch 1: 100%|██████████| 875/875 [00:13<00:00, 66.09it/s, loss=2.27, batch#=875]
# Testing task 0: 219it [00:01, 147.63it/s, batch#=219]
# Training task (ewc) 0, epoch 2: 100%|██████████| 875/875 [00:07<00:00, 119.91it/s, loss=2.2, batch#=875]
# Testing task 0: 219it [00:01, 153.59it/s, batch#=219]
# Training task (ewc) 0, epoch 3: 100%|██████████| 875/875 [00:07<00:00, 120.36it/s, loss=2.09, batch#=875]
# Testing task 0: 219it [00:01, 169.97it/s, batch#=219]
# Training task (ewc) 0, epoch 4: 100%|██████████| 875/875 [00:07<00:00, 119.53it/s, loss=1.89, batch#=875]
# Testing task 0: 219it [00:01, 152.97it/s, batch#=219]
# Training task (ewc) 0, epoch 5: 100%|██████████| 875/875 [00:07<00:00, 120.86it/s, loss=1.58, batch#=875]
# Testing task 0: 219it [00:01, 180.69it/s, batch#=219]
# Training task (ewc) 0, epoch 6: 100%|██████████| 875/875 [00:07<00:00, 124.64it/s, loss=1.25, batch#=875]
# Testing task 0: 219it [00:01, 190.66it/s, batch#=219]
# Training task (ewc) 0, epoch 7: 100%|██████████| 875/875 [00:06<00:00, 127.41it/s, loss=1.01, batch#=875]
# Testing task 0: 219it [00:01, 191.15it/s, batch#=219]
# Training task (ewc) 0, epoch 8: 100%|██████████| 875/875 [00:06<00:00, 127.03it/s, loss=0.849, batch#=875]
# Testing task 0: 219it [00:01, 191.53it/s, batch#=219]
# Training task (ewc) 0, epoch 9: 100%|██████████| 875/875 [00:06<00:00, 129.34it/s, loss=0.739, batch#=875]
# Testing task 0: 219it [00:01, 178.47it/s, batch#=219]
# Training task (ewc) 0, epoch 10: 100%|██████████| 875/875 [00:07<00:00, 119.49it/s, loss=0.66, batch#=875]
# Testing task 0: 219it [00:01, 165.39it/s, batch#=219]
# Testing task 1: 219it [00:01, 178.70it/s, batch#=219]
# Training task (ewc) 1, epoch 1: 100%|██████████| 875/875 [00:08<00:00, 102.96it/s, loss=1.69, batch#=875]
# Testing task 1: 219it [00:01, 185.76it/s, batch#=219]
# Testing task 0: 219it [00:01, 185.84it/s, batch#=219]
# Training task (ewc) 1, epoch 2: 100%|██████████| 875/875 [00:08<00:00, 105.41it/s, loss=1.35, batch#=875]
# Testing task 1: 219it [00:01, 186.95it/s, batch#=219]
# Testing task 0: 219it [00:01, 183.40it/s, batch#=219]
# Training task (ewc) 1, epoch 3: 100%|██████████| 875/875 [00:08<00:00, 99.32it/s, loss=1.23, batch#=875]
# Testing task 1: 219it [00:01, 186.91it/s, batch#=219]
# Testing task 0: 219it [00:01, 184.29it/s, batch#=219]
# Training task (ewc) 1, epoch 4: 100%|██████████| 875/875 [00:09<00:00, 94.64it/s, loss=1.16, batch#=875]
# Testing task 1: 219it [00:01, 159.10it/s, batch#=219]
# Testing task 0: 219it [00:01, 165.83it/s, batch#=219]
# Training task (ewc) 1, epoch 5: 100%|██████████| 875/875 [00:09<00:00, 95.84it/s, loss=1.1, batch#=875]
# Testing task 1: 219it [00:01, 179.08it/s, batch#=219]
# Testing task 0: 219it [00:01, 180.40it/s, batch#=219]
# Training task (ewc) 1, epoch 6: 100%|██████████| 875/875 [00:08<00:00, 100.91it/s, loss=1.06, batch#=875]
# Testing task 1: 219it [00:01, 179.08it/s, batch#=219]
# Testing task 0: 219it [00:01, 179.97it/s, batch#=219]
# Training task (ewc) 1, epoch 7: 100%|██████████| 875/875 [00:08<00:00, 99.70it/s, loss=1.03, batch#=875]
# Testing task 1: 219it [00:01, 145.20it/s, batch#=219]
# Testing task 0: 219it [00:01, 162.93it/s, batch#=219]
# Training task (ewc) 1, epoch 8: 100%|██████████| 875/875 [00:09<00:00, 93.65it/s, loss=1.01, batch#=875]
# Testing task 1: 219it [00:01, 175.20it/s, batch#=219]
# Testing task 0: 219it [00:01, 175.59it/s, batch#=219]
# Training task (ewc) 1, epoch 9: 100%|██████████| 875/875 [00:08<00:00, 101.13it/s, loss=0.983, batch#=875]
# Testing task 1: 219it [00:01, 180.45it/s, batch#=219]
# Testing task 0: 219it [00:01, 177.92it/s, batch#=219]
# Training task (ewc) 1, epoch 10: 100%|██████████| 875/875 [00:09<00:00, 97.17it/s, loss=0.963, batch#=875]
# Testing task 1: 219it [00:01, 169.98it/s, batch#=219]
# Testing task 0: 219it [00:01, 172.30it/s, batch#=219]
# /media/jary/DATA/Uni/tesi/master-thesis-master/utils/datasetsUtils/dataset.py:53: UserWarning: No more tasks...
#   warnings.warn("No more tasks...")

# %%
results_kaf_no_ewt, metrics_kaf_no_ewt = trainer_kaf_no_ewt.all_tasks()
# Out:
# Training task 0, epoch 1: 100%|██████████| 875/875 [00:09<00:00, 91.63it/s, loss=2.27, batch#=875]
# Testing task 0: 219it [00:01, 171.85it/s, batch#=219]
# Training task 0, epoch 2: 100%|██████████| 875/875 [00:06<00:00, 125.34it/s, loss=2.2, batch#=875]
# Testing task 0: 219it [00:01, 189.74it/s, batch#=219]
# Training task 0, epoch 3: 100%|██████████| 875/875 [00:07<00:00, 123.41it/s, loss=2.08, batch#=875]
# Testing task 0: 219it [00:01, 170.26it/s, batch#=219]
# Training task 0, epoch 4: 100%|██████████| 875/875 [00:07<00:00, 122.49it/s, loss=1.87, batch#=875]
# Testing task 0: 219it [00:01, 185.06it/s, batch#=219]
# Training task 0, epoch 5: 100%|██████████| 875/875 [00:06<00:00, 127.07it/s, loss=1.54, batch#=875]
# Testing task 0: 219it [00:01, 187.91it/s, batch#=219]
# Training task 0, epoch 6: 100%|██████████| 875/875 [00:07<00:00, 121.14it/s, loss=1.21, batch#=875]
# Testing task 0: 219it [00:01, 159.86it/s, batch#=219]
# Training task 0, epoch 7: 100%|██████████| 875/875 [00:07<00:00, 121.70it/s, loss=0.97, batch#=875]
# Testing task 0: 219it [00:01, 178.37it/s, batch#=219]
# Training task 0, epoch 8: 100%|██████████| 875/875 [00:07<00:00, 121.85it/s, loss=0.815, batch#=875]
# Testing task 0: 219it [00:01, 178.83it/s, batch#=219]
# Training task 0, epoch 9: 100%|██████████| 875/875 [00:07<00:00, 122.60it/s, loss=0.71, batch#=875]
# Testing task 0: 219it [00:01, 174.95it/s, batch#=219]
# Training task 0, epoch 10: 100%|██████████| 875/875 [00:07<00:00, 118.18it/s, loss=0.635, batch#=875]
# Testing task 0: 219it [00:01, 170.90it/s, batch#=219]
# Testing task 1: 219it [00:01, 168.42it/s, batch#=219]
# Training task 1, epoch 1: 100%|██████████| 875/875 [00:07<00:00, 113.95it/s, loss=1.37, batch#=875]
# Testing task 1: 219it [00:01, 168.58it/s, batch#=219]
# Testing task 0: 219it [00:01, 174.59it/s, batch#=219]
# Training task 1, epoch 2: 100%|██████████| 875/875 [00:07<00:00, 117.42it/s, loss=0.841, batch#=875]
# Testing task 1: 219it [00:01, 163.77it/s, batch#=219]
# Testing task 0: 219it [00:01, 170.64it/s, batch#=219]
# Training task 1, epoch 3: 100%|██████████| 875/875 [00:07<00:00, 118.90it/s, loss=0.686, batch#=875]
# Testing task 1: 219it [00:01, 177.98it/s, batch#=219]
# Testing task 0: 219it [00:01, 179.51it/s, batch#=219]
# Training task 1, epoch 4: 100%|██████████| 875/875 [00:07<00:00, 119.18it/s, loss=0.603, batch#=875]
# Testing task 1: 219it [00:01, 176.63it/s, batch#=219]
# Testing task 0: 219it [00:01, 169.68it/s, batch#=219]
# Training task 1, epoch 5: 100%|██████████| 875/875 [00:07<00:00, 111.84it/s, loss=0.55, batch#=875]
# Testing task 1: 219it [00:01, 167.68it/s, batch#=219]
# Testing task 0: 219it [00:01, 172.35it/s, batch#=219]
# Training task 1, epoch 6: 100%|██████████| 875/875 [00:07<00:00, 111.79it/s, loss=0.513, batch#=875]
# Testing task 1: 219it [00:01, 174.17it/s, batch#=219]
# Testing task 0: 219it [00:01, 149.82it/s, batch#=219]
# Training task 1, epoch 7: 100%|██████████| 875/875 [00:07<00:00, 113.56it/s, loss=0.485, batch#=875]
# Testing task 1: 219it [00:01, 177.67it/s, batch#=219]
# Testing task 0: 219it [00:01, 180.91it/s, batch#=219]
# Training task 1, epoch 8: 100%|██████████| 875/875 [00:07<00:00, 121.27it/s, loss=0.462, batch#=875]
# Testing task 1: 219it [00:01, 170.30it/s, batch#=219]
# Testing task 0: 219it [00:01, 174.23it/s, batch#=219]
# Training task 1, epoch 9: 100%|██████████| 875/875 [00:07<00:00, 117.35it/s, loss=0.444, batch#=875]
# Testing task 1: 219it [00:01, 175.51it/s, batch#=219]
# Testing task 0: 219it [00:01, 168.45it/s, batch#=219]
# Training task 1, epoch 10: 100%|██████████| 875/875 [00:07<00:00, 116.05it/s, loss=0.429, batch#=875]
# Testing task 1: 219it [00:01, 171.87it/s, batch#=219]
# Testing task 0: 219it [00:01, 164.30it/s, batch#=219]

# %%
results_ewt, metrics_ewt = trainer_ewt.all_tasks()
# Out:
# Training task (ewc) 0, epoch 1: 100%|██████████| 875/875 [00:05<00:00, 155.74it/s, loss=2.3, batch#=875]
# Testing task 0: 219it [00:01, 216.65it/s, batch#=219]
# Training task (ewc) 0, epoch 2: 100%|██████████| 875/875 [00:04<00:00, 184.16it/s, loss=2.29, batch#=875]
# Testing task 0: 219it [00:01, 195.64it/s, batch#=219]
# Training task (ewc) 0, epoch 3: 100%|██████████| 875/875 [00:05<00:00, 167.06it/s, loss=2.28, batch#=875]
# Testing task 0: 219it [00:01, 209.58it/s, batch#=219]
# Training task (ewc) 0, epoch 4: 100%|██████████| 875/875 [00:05<00:00, 167.35it/s, loss=2.26, batch#=875]
# Testing task 0: 219it [00:00, 229.94it/s, batch#=219]
# Training task (ewc) 0, epoch 5: 100%|██████████| 875/875 [00:05<00:00, 172.89it/s, loss=2.24, batch#=875]
# Testing task 0: 219it [00:01, 203.59it/s, batch#=219]
# Training task (ewc) 0, epoch 6: 100%|██████████| 875/875 [00:05<00:00, 174.47it/s, loss=2.21, batch#=875]
# Testing task 0: 219it [00:00, 219.35it/s, batch#=219]
# Training task (ewc) 0, epoch 7: 100%|██████████| 875/875 [00:05<00:00, 169.76it/s, loss=2.16, batch#=875]
# Testing task 0: 219it [00:01, 198.70it/s, batch#=219]
# Training task (ewc) 0, epoch 8: 100%|██████████| 875/875 [00:04<00:00, 188.56it/s, loss=2.07, batch#=875]
# Testing task 0: 219it [00:00, 221.41it/s, batch#=219]
# Training task (ewc) 0, epoch 9: 100%|██████████| 875/875 [00:04<00:00, 189.15it/s, loss=1.92, batch#=875]
# Testing task 0: 219it [00:01, 216.36it/s, batch#=219]
# Training task (ewc) 0, epoch 10: 100%|██████████| 875/875 [00:04<00:00, 184.25it/s, loss=1.68, batch#=875]
# Testing task 0: 219it [00:00, 225.11it/s, batch#=219]
# Testing task 1: 219it [00:00, 228.34it/s, batch#=219]
# Training task (ewc) 1, epoch 1: 100%|██████████| 875/875 [00:06<00:00, 141.26it/s, loss=2.12, batch#=875]
# Testing task 1: 219it [00:00, 242.04it/s, batch#=219]
# Testing task 0: 219it [00:00, 233.53it/s, batch#=219]
# Training task (ewc) 1, epoch 2: 100%|██████████| 875/875 [00:06<00:00, 145.18it/s, loss=1.92, batch#=875]
# Testing task 1: 219it [00:00, 226.33it/s, batch#=219]
# Testing task 0: 219it [00:00, 232.23it/s, batch#=219]
# Training task (ewc) 1, epoch 3: 100%|██████████| 875/875 [00:06<00:00, 142.95it/s, loss=1.78, batch#=875]
# Testing task 1: 219it [00:00, 220.62it/s, batch#=219]
# Testing task 0: 219it [00:00, 225.86it/s, batch#=219]
# Training task (ewc) 1, epoch 4: 100%|██████████| 875/875 [00:06<00:00, 142.52it/s, loss=1.67, batch#=875]
# Testing task 1: 219it [00:00, 235.72it/s, batch#=219]
# Testing task 0: 219it [00:00, 232.63it/s, batch#=219]
# Training task (ewc) 1, epoch 5: 100%|██████████| 875/875 [00:06<00:00, 142.42it/s, loss=1.57, batch#=875]
# Testing task 1: 219it [00:00, 231.48it/s, batch#=219]
# Testing task 0: 219it [00:00, 243.72it/s, batch#=219]
# Training task (ewc) 1, epoch 6: 100%|██████████| 875/875 [00:06<00:00, 145.32it/s, loss=1.49, batch#=875]
# Testing task 1: 219it [00:00, 241.80it/s, batch#=219]
# Testing task 0: 219it [00:00, 219.53it/s, batch#=219]
# Training task (ewc) 1, epoch 7: 100%|██████████| 875/875 [00:06<00:00, 125.19it/s, loss=1.43, batch#=875]
# Testing task 1: 219it [00:01, 185.22it/s, batch#=219]
# Testing task 0: 219it [00:01, 202.67it/s, batch#=219]
# Training task (ewc) 1, epoch 8: 100%|██████████| 875/875 [00:06<00:00, 136.13it/s, loss=1.37, batch#=875]
# Testing task 1: 219it [00:00, 220.11it/s, batch#=219]
# Testing task 0: 219it [00:00, 226.23it/s, batch#=219]
# Training task (ewc) 1, epoch 9: 100%|██████████| 875/875 [00:06<00:00, 130.98it/s, loss=1.32, batch#=875]
# Testing task 1: 219it [00:00, 222.60it/s, batch#=219]
# Testing task 0: 219it [00:00, 223.45it/s, batch#=219]
# Training task (ewc) 1, epoch 10: 100%|██████████| 875/875 [00:06<00:00, 129.03it/s, loss=1.27, batch#=875]
# Testing task 1: 219it [00:01, 185.07it/s, batch#=219]
# Testing task 0: 219it [00:01, 203.07it/s, batch#=219]

# %%
results_no_ewt, metrics_no_ewt = trainer_no_ewt.all_tasks()
# Out:
# Training task 0, epoch 1: 100%|██████████| 875/875 [00:05<00:00, 172.15it/s, loss=2.3, batch#=875]
# Testing task 0: 219it [00:01, 194.03it/s, batch#=219]
# Training task 0, epoch 2: 100%|██████████| 875/875 [00:05<00:00, 166.70it/s, loss=2.29, batch#=875]
# Testing task 0: 219it [00:01, 216.18it/s, batch#=219]
# Training task 0, epoch 3: 100%|██████████| 875/875 [00:04<00:00, 189.88it/s, loss=2.28, batch#=875]
# Testing task 0: 219it [00:00, 236.65it/s, batch#=219]
# Training task 0, epoch 4: 100%|██████████| 875/875 [00:04<00:00, 190.23it/s, loss=2.26, batch#=875]
# Testing task 0: 219it [00:00, 226.23it/s, batch#=219]
# Training task 0, epoch 5: 100%|██████████| 875/875 [00:05<00:00, 164.89it/s, loss=2.24, batch#=875]
# Testing task 0: 219it [00:01, 208.73it/s, batch#=219]
# Training task 0, epoch 6: 100%|██████████| 875/875 [00:04<00:00, 181.67it/s, loss=2.21, batch#=875]
# Testing task 0: 219it [00:01, 217.89it/s, batch#=219]
# Training task 0, epoch 7: 100%|██████████| 875/875 [00:04<00:00, 185.23it/s, loss=2.16, batch#=875]
# Testing task 0: 219it [00:01, 200.72it/s, batch#=219]
# Training task 0, epoch 8: 100%|██████████| 875/875 [00:04<00:00, 196.72it/s, loss=2.07, batch#=875]
# Testing task 0: 219it [00:00, 231.43it/s, batch#=219]
# Training task 0, epoch 9: 100%|██████████| 875/875 [00:05<00:00, 174.56it/s, loss=1.92, batch#=875]
# Testing task 0: 219it [00:01, 180.77it/s, batch#=219]
# Training task 0, epoch 10: 100%|██████████| 875/875 [00:04<00:00, 183.24it/s, loss=1.68, batch#=875]
# Testing task 0: 219it [00:00, 239.25it/s, batch#=219]
# Testing task 1: 219it [00:01, 218.51it/s, batch#=219]
# Training task 1, epoch 1: 100%|██████████| 875/875 [00:05<00:00, 170.49it/s, loss=2.07, batch#=875]
# Testing task 1: 219it [00:00, 231.56it/s, batch#=219]
# Testing task 0: 219it [00:00, 230.76it/s, batch#=219]
# Training task 1, epoch 2: 100%|██████████| 875/875 [00:04<00:00, 176.95it/s, loss=1.68, batch#=875]
# Testing task 1: 219it [00:00, 227.84it/s, batch#=219]
# Testing task 0: 219it [00:00, 231.44it/s, batch#=219]
# Training task 1, epoch 3: 100%|██████████| 875/875 [00:04<00:00, 187.00it/s, loss=1.36, batch#=875]
# Testing task 1: 219it [00:01, 195.46it/s, batch#=219]
# Testing task 0: 219it [00:00, 223.32it/s, batch#=219]
# Training task 1, epoch 4: 100%|██████████| 875/875 [00:04<00:00, 175.01it/s, loss=1.12, batch#=875]
# Testing task 1: 219it [00:01, 210.94it/s, batch#=219]
# Testing task 0: 219it [00:01, 208.92it/s, batch#=219]
# Training task 1, epoch 5: 100%|██████████| 875/875 [00:04<00:00, 198.31it/s, loss=0.961, batch#=875]
# Testing task 1: 219it [00:00, 239.11it/s, batch#=219]
# Testing task 0: 219it [00:00, 237.78it/s, batch#=219]
# Training task 1, epoch 6: 100%|██████████| 875/875 [00:04<00:00, 198.57it/s, loss=0.851, batch#=875]
# Testing task 1: 219it [00:00, 230.94it/s, batch#=219]
# Testing task 0: 219it [00:00, 228.52it/s, batch#=219]
# Training task 1, epoch 7: 100%|██████████| 875/875 [00:04<00:00, 197.35it/s, loss=0.774, batch#=875]
# Testing task 1: 219it [00:00, 240.34it/s, batch#=219]
# Testing task 0: 219it [00:00, 239.86it/s, batch#=219]
# Training task 1, epoch 8: 100%|██████████| 875/875 [00:04<00:00, 198.08it/s, loss=0.715, batch#=875]
# Testing task 1: 219it [00:00, 235.39it/s, batch#=219]
# Testing task 0: 219it [00:00, 234.71it/s, batch#=219]
# Training task 1, epoch 9: 100%|██████████| 875/875 [00:04<00:00, 200.86it/s, loss=0.668, batch#=875]
# Testing task 1: 219it [00:00, 237.66it/s, batch#=219]
# Testing task 0: 219it [00:00, 239.81it/s, batch#=219]
# Training task 1, epoch 10: 100%|██████████| 875/875 [00:04<00:00, 185.12it/s, loss=0.629, batch#=875]
# Testing task 1: 219it [00:00, 226.77it/s, batch#=219]
# Testing task 0: 219it [00:00, 230.10it/s, batch#=219]

# %%
n_task = len(metrics_ewt['tasks'])
tot_epochs = 0

print('No ewc', metrics_no_ewt['metrics'])
print('Ewc', metrics_ewt['metrics'])

print('KAF no ewc', metrics_kaf_no_ewt['metrics'])
print('KAF ewc', metrics_kaf_ewt['metrics'])

for k, v in metrics_no_ewt['tasks'].items():
    tot_epochs = max(tot_epochs, len(v['accuracy']))
             
for k, v in metrics_ewt['tasks'].items():
    tot_epochs = max(tot_epochs, len(v['accuracy']))
      
fig = plt.figure(figsize=(12, 24))

ax = None
for i, task in enumerate(metrics_ewt['tasks'].keys()):
        
    ewt = metrics_ewt['tasks'][task]
    no_ewt = metrics_no_ewt['tasks'][task]
    
    kaf_ewt = metrics_kaf_ewt['tasks'][task]
    kaf_no_ewt = metrics_kaf_no_ewt['tasks'][task]
    

    x = list(range(tot_epochs-len(ewt['accuracy']), tot_epochs))
    x = [i+1 for i in x]

    ax = fig.add_subplot(n_task, 1, i+1, sharex=ax) 
    
    ax.plot(x, ewt['f1'], label='ewt')
    ax.plot(x, no_ewt['f1'], label='no ewt')
    ax.plot(x, kaf_ewt['f1'], label='kaf ewt')
    ax.plot(x, kaf_no_ewt['f1'], label='kaf no ewt')
    
    ax.set_xticks([1, 11, 20],minor=False)
    
    ax.set_title("Task {}".format(task))
    ax.legend(loc="lower left")
    ax.xaxis.grid(True)
    
fig.subplots_adjust(hspace=0.01)
# Out:
# No ewc {'fwt': 0.6985714285714286, 'bwt': 0.005714285714285783, 'remembering': 1, 'pbwt': 0.005714285714285783, 'accuracy': 0.5650000000000001}
# Ewc {'fwt': 0.7219285714285715, 'bwt': 0.029642857142857193, 'remembering': 1, 'pbwt': 0.029642857142857193, 'accuracy': 0.5489285714285714}
# KAF no ewc {'fwt': 0.835, 'bwt': -0.01828571428571435, 'remembering': 0.9817142857142857, 'pbwt': 0, 'accuracy': 0.6304285714285714}
# KAF ewc {'fwt': 0.7947857142857143, 'bwt': -0.05257142857142849, 'remembering': 0.9474285714285715, 'pbwt': 0, 'accuracy': 0.6044999999999999}
