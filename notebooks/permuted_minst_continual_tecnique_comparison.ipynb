# %%
import sys
import os
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from networks import NoKafnet, Kafnet
import utils.datasetsUtils.MINST as MINST
from utils.datasetsUtils.taskManager import SingleTargetClassificationTask, NoTask
import configs.configClasses as configClasses
from torchvision.transforms import transforms
import torch
import networks.continual_learning as continual_learning
from Trainer import Trainer
import matplotlib.pyplot as plt
from collections import defaultdict
from copy import deepcopy
import numpy as np

# %%
torch.manual_seed(0)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
np.random.seed(0)

# %%
print(torch.cuda.is_available())
print(torch.cuda.device_count())
print(torch.cuda.get_device_name(torch.cuda.current_device()))
# Out:
# True
# 1
# GeForce GTX 1050

# %%
configOnline = configClasses.OnlineLearningConfig()
configOnline.L1_REG = 0
configOnline.EPOCHS = 20
configOnline.SAVE_PATH = './models/permuted_minst/tecnique_comparison'
configOnline.IS_CONVOLUTIONAL = False
configOnline.MODEL_NAME = ''
print(configOnline)
# Out:
# CONFIG PARAMETERS
# BATCH_SIZE: 64
# DEVICE: cuda
# EPOCHS: 20
# EWC_IMPORTANCE: 1000
# EWC_SAMPLE_SIZE: 250
# EWC_TYPE: <class 'networks.continual_learning.OnlineEWC'>
# GAMMA: 1.0
# IS_CONVOLUTIONAL: False
# ITERS: 1
# L1_REG: 0
# LOSS: cross_entropy
# LR: 0.001
# MODEL_NAME:
# OPTIMIZER: SGD
# RUN_NAME: default
# SAVE_PATH: ./models/permuted_minst/tecnique_comparison
# USE_EWC: True
# USE_TENSORBOARD: True

# %%
dataset = MINST.PermutedMINST('../data/minst', download=True, n_permutation=4,
                        force_download=False, train_split=0.8, transform=None, target_transform=None)
dataset.load_dataset()
# Out:
# ../data/minst/download
# task #0 with train 56000 and test 14000 images (label: 0)
# task #1 with train 56000 and test 14000 images (label: 1)
# task #2 with train 56000 and test 14000 images (label: 2)
# task #3 with train 56000 and test 14000 images (label: 3)

# %%
net = NoKafnet.MLP(len(dataset.class_to_idx))

# %%
results = []
experiments = [('no_cont_learning', None), 
               ('ewc', continual_learning.OnlineEWC), 
               ('gem', continual_learning.GEM)]

# %%
for name, tec in experiments:
    print(name)
    
    n = deepcopy(net)
    config = deepcopy(configOnline)
    
    config.MODEL_NAME = name

    if 'name' == 'gem':
        config.EWC_IMPORTANCE = 0.5
    config.EWC_TYPE = tec
    
    trainer = Trainer(n, deepcopy(dataset), config)

    r = trainer.load()
    if not r:
        r = trainer.all_tasks()
    
    results.append((name, r))
    
    del trainer
    del n
# Out:
# no_cont_learning
# /media/jary/DATA/Uni/tesi/codice/Trainer.py:37: UserWarning: Ewc type is set to None
#   warnings.warn("Ewc type is set to None  ")
# ewc
# gem

# %%
kaf = Kafnet.KAFMLP(len(dataset.class_to_idx), hidden_size=int(400*0.7))

# %%
experiments_kaf = [('kaf_no_cont_learning', None), 
               ('kaf_ewc', continual_learning.OnlineEWC), 
               ('kaf_gem', continual_learning.GEM)]
results_kaf = []

# %%
for name, tec in experiments_kaf:
    print(name)
    
    n = deepcopy(kaf)
    config = deepcopy(configOnline)
    
    config.MODEL_NAME = name

    if 'name' == 'gem':
        config.EWC_IMPORTANCE = 0.5
    config.EWC_TYPE = tec
    
    trainer = Trainer(n, deepcopy(dataset), config)

    r = trainer.load()
    if not r:
        r = trainer.all_tasks()
    
    results_kaf.append((name, r))
    
    del trainer
    del n
# Out:
# kaf_no_cont_learning
# kaf_ewc
# kaf_gem
# Training task (ewc) 0, epoch 1: 100%|██████████| 875/875 [00:08<00:00, 108.32it/s, loss=2.27, batch#=875]
# Testing task 0: 219it [00:01, 169.61it/s, batch#=219]
# Training task (ewc) 0, epoch 2: 100%|██████████| 875/875 [00:06<00:00, 141.69it/s, loss=2.21, batch#=875]
# Testing task 0: 219it [00:01, 209.79it/s, batch#=219]
# Training task (ewc) 0, epoch 3: 100%|██████████| 875/875 [00:06<00:00, 141.84it/s, loss=2.11, batch#=875]
# Testing task 0: 219it [00:01, 203.54it/s, batch#=219]
# Training task (ewc) 0, epoch 4: 100%|██████████| 875/875 [00:06<00:00, 140.32it/s, loss=1.93, batch#=875]
# Testing task 0: 219it [00:01, 208.54it/s, batch#=219]
# Training task (ewc) 0, epoch 5: 100%|██████████| 875/875 [00:06<00:00, 141.87it/s, loss=1.63, batch#=875]
# Testing task 0: 219it [00:01, 208.50it/s, batch#=219]
# Training task (ewc) 0, epoch 6: 100%|██████████| 875/875 [00:06<00:00, 141.55it/s, loss=1.31, batch#=875]
# Testing task 0: 219it [00:01, 207.27it/s, batch#=219]
# Training task (ewc) 0, epoch 7: 100%|██████████| 875/875 [00:06<00:00, 126.72it/s, loss=1.06, batch#=875]
# Testing task 0: 219it [00:01, 199.89it/s, batch#=219]
# Training task (ewc) 0, epoch 8: 100%|██████████| 875/875 [00:06<00:00, 127.94it/s, loss=0.897, batch#=875]
# Testing task 0: 219it [00:01, 168.92it/s, batch#=219]
# Training task (ewc) 0, epoch 9: 100%|██████████| 875/875 [00:06<00:00, 132.36it/s, loss=0.784, batch#=875]
# Testing task 0: 219it [00:01, 197.01it/s, batch#=219]
# Training task (ewc) 0, epoch 10: 100%|██████████| 875/875 [00:06<00:00, 132.46it/s, loss=0.702, batch#=875]
# Testing task 0: 219it [00:01, 207.50it/s, batch#=219]
# Training task (ewc) 0, epoch 11: 100%|██████████| 875/875 [00:06<00:00, 129.48it/s, loss=0.639, batch#=875]
# Testing task 0: 219it [00:01, 190.34it/s, batch#=219]
# Training task (ewc) 0, epoch 12: 100%|██████████| 875/875 [00:06<00:00, 132.00it/s, loss=0.588, batch#=875]
# Testing task 0: 219it [00:01, 201.29it/s, batch#=219]
# Training task (ewc) 0, epoch 13: 100%|██████████| 875/875 [00:06<00:00, 140.39it/s, loss=0.547, batch#=875]
# Testing task 0: 219it [00:01, 196.30it/s, batch#=219]
# Training task (ewc) 0, epoch 14: 100%|██████████| 875/875 [00:06<00:00, 135.92it/s, loss=0.514, batch#=875]
# Testing task 0: 219it [00:01, 208.39it/s, batch#=219]
# Training task (ewc) 0, epoch 15: 100%|██████████| 875/875 [00:06<00:00, 141.36it/s, loss=0.487, batch#=875]
# Testing task 0: 219it [00:01, 207.72it/s, batch#=219]
# Training task (ewc) 0, epoch 16: 100%|██████████| 875/875 [00:06<00:00, 141.78it/s, loss=0.464, batch#=875]
# Testing task 0: 219it [00:01, 206.83it/s, batch#=219]
# Training task (ewc) 0, epoch 17: 100%|██████████| 875/875 [00:06<00:00, 141.08it/s, loss=0.445, batch#=875]
# Testing task 0: 219it [00:01, 207.14it/s, batch#=219]
# Training task (ewc) 0, epoch 18: 100%|██████████| 875/875 [00:06<00:00, 135.11it/s, loss=0.43, batch#=875]
# Testing task 0: 219it [00:01, 195.01it/s, batch#=219]
# Training task (ewc) 0, epoch 19: 100%|██████████| 875/875 [00:06<00:00, 141.07it/s, loss=0.417, batch#=875]
# Testing task 0: 219it [00:01, 206.55it/s, batch#=219]
# Training task (ewc) 0, epoch 20: 100%|██████████| 875/875 [00:06<00:00, 139.85it/s, loss=0.405, batch#=875]
# Testing task 0: 219it [00:01, 195.46it/s, batch#=219]
# Testing task 1: 219it [00:01, 185.15it/s, batch#=219]
# Testing task 2: 219it [00:01, 174.11it/s, batch#=219]
# Testing task 3: 219it [00:01, 189.33it/s, batch#=219]
# Training task (ewc) 1, epoch 1: 100%|██████████| 875/875 [00:20<00:00, 43.59it/s, loss=1.67, batch#=875]
# Testing task 1: 219it [00:01, 190.98it/s, batch#=219]
# Testing task 0: 219it [00:01, 199.94it/s, batch#=219]
# Training task (ewc) 1, epoch 2: 100%|██████████| 875/875 [00:17<00:00, 49.08it/s, loss=0.975, batch#=875]
# Testing task 1: 219it [00:01, 168.53it/s, batch#=219]
# Testing task 0: 219it [00:01, 169.09it/s, batch#=219]
# Training task (ewc) 1, epoch 3: 100%|██████████| 875/875 [00:19<00:00, 45.62it/s, loss=0.781, batch#=875]
# Testing task 1: 219it [00:01, 205.40it/s, batch#=219]
# Testing task 0: 219it [00:01, 209.81it/s, batch#=219]
# Training task (ewc) 1, epoch 4: 100%|██████████| 875/875 [00:18<00:00, 47.31it/s, loss=0.736, batch#=875]
# Testing task 1: 219it [00:01, 155.91it/s, batch#=219]
# Testing task 0: 219it [00:01, 174.65it/s, batch#=219]
# Training task (ewc) 1, epoch 5: 100%|██████████| 875/875 [00:20<00:00, 42.99it/s, loss=0.72, batch#=875]
# Testing task 1: 219it [00:01, 200.43it/s, batch#=219]
# Testing task 0: 219it [00:01, 171.87it/s, batch#=219]
# Training task (ewc) 1, epoch 6: 100%|██████████| 875/875 [00:18<00:00, 47.24it/s, loss=0.708, batch#=875]
# Testing task 1: 219it [00:01, 196.54it/s, batch#=219]
# Testing task 0: 219it [00:01, 196.02it/s, batch#=219]
# Training task (ewc) 1, epoch 7: 100%|██████████| 875/875 [00:19<00:00, 46.56it/s, loss=0.693, batch#=875]
# Testing task 1: 219it [00:01, 191.20it/s, batch#=219]
# Testing task 0: 219it [00:01, 195.80it/s, batch#=219]
# Training task (ewc) 1, epoch 8: 100%|██████████| 875/875 [00:18<00:00, 47.83it/s, loss=0.669, batch#=875]
# Testing task 1: 219it [00:01, 206.53it/s, batch#=219]
# Testing task 0: 219it [00:01, 204.49it/s, batch#=219]
# Training task (ewc) 1, epoch 9: 100%|██████████| 875/875 [00:18<00:00, 46.70it/s, loss=0.663, batch#=875]
# Testing task 1: 219it [00:01, 167.77it/s, batch#=219]
# Testing task 0: 219it [00:01, 170.42it/s, batch#=219]
# Training task (ewc) 1, epoch 10: 100%|██████████| 875/875 [00:19<00:00, 45.27it/s, loss=0.636, batch#=875]
# Testing task 1: 219it [00:01, 201.44it/s, batch#=219]
# Testing task 0: 219it [00:01, 199.98it/s, batch#=219]
# Training task (ewc) 1, epoch 11: 100%|██████████| 875/875 [00:18<00:00, 48.53it/s, loss=0.616, batch#=875]
# Testing task 1: 219it [00:01, 190.19it/s, batch#=219]
# Testing task 0: 219it [00:01, 196.65it/s, batch#=219]
# Training task (ewc) 1, epoch 12: 100%|██████████| 875/875 [00:17<00:00, 51.97it/s, loss=0.579, batch#=875]
# Testing task 1: 219it [00:01, 191.47it/s, batch#=219]
# Testing task 0: 219it [00:01, 208.58it/s, batch#=219]
# Training task (ewc) 1, epoch 13: 100%|██████████| 875/875 [00:17<00:00, 49.18it/s, loss=0.572, batch#=875]
# Testing task 1: 219it [00:01, 197.97it/s, batch#=219]
# Testing task 0: 219it [00:01, 198.71it/s, batch#=219]
# Training task (ewc) 1, epoch 14: 100%|██████████| 875/875 [00:17<00:00, 47.46it/s, loss=0.544, batch#=875]
# Testing task 1: 219it [00:01, 192.58it/s, batch#=219]
# Testing task 0: 219it [00:01, 206.95it/s, batch#=219]
# Training task (ewc) 1, epoch 15: 100%|██████████| 875/875 [00:18<00:00, 48.53it/s, loss=0.522, batch#=875]
# Testing task 1: 219it [00:01, 199.38it/s, batch#=219]
# Testing task 0: 219it [00:01, 201.84it/s, batch#=219]
# Training task (ewc) 1, epoch 16: 100%|██████████| 875/875 [00:18<00:00, 48.06it/s, loss=0.524, batch#=875]
# Testing task 1: 219it [00:01, 192.82it/s, batch#=219]
# Testing task 0: 219it [00:01, 173.76it/s, batch#=219]
# Training task (ewc) 1, epoch 17: 100%|██████████| 875/875 [00:18<00:00, 47.71it/s, loss=0.543, batch#=875]
# Testing task 1: 219it [00:01, 210.31it/s, batch#=219]
# Testing task 0: 219it [00:01, 207.03it/s, batch#=219]
# Training task (ewc) 1, epoch 18: 100%|██████████| 875/875 [00:18<00:00, 47.98it/s, loss=0.539, batch#=875]
# Testing task 1: 219it [00:01, 196.94it/s, batch#=219]
# Testing task 0: 219it [00:01, 178.12it/s, batch#=219]
# Training task (ewc) 1, epoch 19: 100%|██████████| 875/875 [00:17<00:00, 50.06it/s, loss=0.538, batch#=875]
# Testing task 1: 219it [00:01, 207.68it/s, batch#=219]
# Testing task 0: 219it [00:01, 208.74it/s, batch#=219]
# Training task (ewc) 1, epoch 20: 100%|██████████| 875/875 [00:17<00:00, 48.83it/s, loss=0.519, batch#=875]
# Testing task 1: 219it [00:01, 173.90it/s, batch#=219]
# Testing task 0: 219it [00:01, 172.76it/s, batch#=219]
# Testing task 2: 219it [00:01, 170.44it/s, batch#=219]
# Testing task 3: 219it [00:01, 206.62it/s, batch#=219]
# Training task (ewc) 2, epoch 1: 100%|██████████| 875/875 [00:27<00:00, 31.89it/s, loss=3.08, batch#=875]
# Testing task 2: 219it [00:01, 206.87it/s, batch#=219]
# Testing task 0: 219it [00:01, 200.97it/s, batch#=219]
# Testing task 1: 219it [00:01, 198.97it/s, batch#=219]
# Training task (ewc) 2, epoch 2: 100%|██████████| 875/875 [00:27<00:00, 32.38it/s, loss=1.63, batch#=875]
# Testing task 2: 219it [00:01, 202.38it/s, batch#=219]
# Testing task 0: 219it [00:01, 205.25it/s, batch#=219]
# Testing task 1: 219it [00:01, 201.17it/s, batch#=219]
# Training task (ewc) 2, epoch 3: 100%|██████████| 875/875 [00:27<00:00, 28.19it/s, loss=1.25, batch#=875]
# Testing task 2: 219it [00:01, 188.91it/s, batch#=219]
# Testing task 0: 219it [00:01, 200.55it/s, batch#=219]
# Testing task 1: 219it [00:01, 202.57it/s, batch#=219]
# Training task (ewc) 2, epoch 4: 100%|██████████| 875/875 [00:27<00:00, 31.47it/s, loss=1.01, batch#=875]
# Testing task 2: 219it [00:01, 202.03it/s, batch#=219]
# Testing task 0: 219it [00:01, 196.57it/s, batch#=219]
# Testing task 1: 219it [00:01, 212.73it/s, batch#=219]
# Training task (ewc) 2, epoch 5: 100%|██████████| 875/875 [00:28<00:00, 31.20it/s, loss=0.902, batch#=875]
# Testing task 2: 219it [00:01, 188.95it/s, batch#=219]
# Testing task 0: 219it [00:01, 197.73it/s, batch#=219]
# Testing task 1: 219it [00:01, 194.02it/s, batch#=219]
# Training task (ewc) 2, epoch 6: 100%|██████████| 875/875 [00:29<00:00, 26.15it/s, loss=0.823, batch#=875]
# Testing task 2: 219it [00:01, 168.90it/s, batch#=219]
# Testing task 0: 219it [00:01, 183.53it/s, batch#=219]
# Testing task 1: 219it [00:01, 164.28it/s, batch#=219]
# Training task (ewc) 2, epoch 7: 100%|██████████| 875/875 [00:29<00:00, 30.57it/s, loss=0.76, batch#=875]
# Testing task 2: 219it [00:01, 200.53it/s, batch#=219]
# Testing task 0: 219it [00:01, 209.15it/s, batch#=219]
# Testing task 1: 219it [00:01, 199.70it/s, batch#=219]
# Training task (ewc) 2, epoch 8: 100%|██████████| 875/875 [00:29<00:00, 35.66it/s, loss=0.716, batch#=875]
# Testing task 2: 219it [00:01, 200.81it/s, batch#=219]
# Testing task 0: 219it [00:01, 202.56it/s, batch#=219]
# Testing task 1: 219it [00:01, 202.65it/s, batch#=219]
# Training task (ewc) 2, epoch 9: 100%|██████████| 875/875 [00:27<00:00, 31.98it/s, loss=0.67, batch#=875]
# Testing task 2: 219it [00:01, 180.61it/s, batch#=219]
# Testing task 0: 219it [00:01, 192.97it/s, batch#=219]
# Testing task 1: 219it [00:01, 190.73it/s, batch#=219]
# Training task (ewc) 2, epoch 10: 100%|██████████| 875/875 [00:30<00:00, 28.88it/s, loss=0.637, batch#=875]
# Testing task 2: 219it [00:01, 187.08it/s, batch#=219]
# Testing task 0: 219it [00:01, 195.36it/s, batch#=219]
# Testing task 1: 219it [00:01, 188.48it/s, batch#=219]
# Training task (ewc) 2, epoch 11: 100%|██████████| 875/875 [00:29<00:00, 29.75it/s, loss=0.608, batch#=875]
# Testing task 2: 219it [00:01, 193.59it/s, batch#=219]
# Testing task 0: 219it [00:01, 190.88it/s, batch#=219]
# Testing task 1: 219it [00:01, 187.01it/s, batch#=219]
# Training task (ewc) 2, epoch 12: 100%|██████████| 875/875 [00:29<00:00, 29.73it/s, loss=0.586, batch#=875]
# Testing task 2: 219it [00:01, 181.04it/s, batch#=219]
# Testing task 0: 219it [00:01, 165.46it/s, batch#=219]
# Testing task 1: 219it [00:01, 171.11it/s, batch#=219]
# Training task (ewc) 2, epoch 13: 100%|██████████| 875/875 [00:29<00:00, 29.64it/s, loss=0.572, batch#=875]
# Testing task 2: 219it [00:01, 179.03it/s, batch#=219]
# Testing task 0: 219it [00:01, 190.27it/s, batch#=219]
# Testing task 1: 219it [00:01, 191.18it/s, batch#=219]
# Training task (ewc) 2, epoch 14: 100%|██████████| 875/875 [00:28<00:00, 32.23it/s, loss=0.548, batch#=875]
# Testing task 2: 219it [00:01, 202.69it/s, batch#=219]
# Testing task 0: 219it [00:01, 207.62it/s, batch#=219]
# Testing task 1: 219it [00:01, 203.36it/s, batch#=219]
# Training task (ewc) 2, epoch 15: 100%|██████████| 875/875 [00:26<00:00, 32.68it/s, loss=0.532, batch#=875]
# Testing task 2: 219it [00:01, 200.77it/s, batch#=219]
# Testing task 0: 219it [00:01, 197.19it/s, batch#=219]
# Testing task 1: 219it [00:01, 190.68it/s, batch#=219]
# Training task (ewc) 2, epoch 16: 100%|██████████| 875/875 [00:29<00:00, 30.04it/s, loss=0.524, batch#=875]
# Testing task 2: 219it [00:01, 204.35it/s, batch#=219]
# Testing task 0: 219it [00:01, 207.93it/s, batch#=219]
# Testing task 1: 219it [00:01, 205.65it/s, batch#=219]
# Training task (ewc) 2, epoch 17: 100%|██████████| 875/875 [00:28<00:00, 30.91it/s, loss=0.514, batch#=875]
# Testing task 2: 219it [00:01, 192.59it/s, batch#=219]
# Testing task 0: 219it [00:01, 186.30it/s, batch#=219]
# Testing task 1: 219it [00:01, 206.60it/s, batch#=219]
# Training task (ewc) 2, epoch 18: 100%|██████████| 875/875 [00:27<00:00, 32.10it/s, loss=0.511, batch#=875]
# Testing task 2: 219it [00:01, 210.40it/s, batch#=219]
# Testing task 0: 219it [00:01, 199.79it/s, batch#=219]
# Testing task 1: 219it [00:01, 190.54it/s, batch#=219]
# Training task (ewc) 2, epoch 19: 100%|██████████| 875/875 [00:28<00:00, 30.30it/s, loss=0.499, batch#=875]
# Testing task 2: 219it [00:01, 195.69it/s, batch#=219]
# Testing task 0: 219it [00:01, 175.32it/s, batch#=219]
# Testing task 1: 219it [00:01, 176.62it/s, batch#=219]
# Training task (ewc) 2, epoch 20: 100%|██████████| 875/875 [00:29<00:00, 29.66it/s, loss=0.493, batch#=875]
# Testing task 2: 219it [00:01, 188.68it/s, batch#=219]
# Testing task 0: 219it [00:01, 192.78it/s, batch#=219]
# Testing task 1: 219it [00:01, 167.80it/s, batch#=219]
# Testing task 3: 219it [00:01, 165.53it/s, batch#=219]
# Training task (ewc) 3, epoch 1: 100%|██████████| 875/875 [00:39<00:00, 21.63it/s, loss=4.69, batch#=875]
# Testing task 3: 219it [00:01, 175.55it/s, batch#=219]
# Testing task 0: 219it [00:01, 182.86it/s, batch#=219]
# Testing task 1: 219it [00:01, 186.40it/s, batch#=219]
# Testing task 2: 219it [00:01, 184.61it/s, batch#=219]
# Training task (ewc) 3, epoch 2: 100%|██████████| 875/875 [00:36<00:00, 25.11it/s, loss=3.64, batch#=875]
# Testing task 3: 219it [00:01, 206.23it/s, batch#=219]
# Testing task 0: 219it [00:01, 205.27it/s, batch#=219]
# Testing task 1: 219it [00:01, 198.09it/s, batch#=219]
# Testing task 2: 219it [00:01, 199.98it/s, batch#=219]
# Training task (ewc) 3, epoch 3: 100%|██████████| 875/875 [00:38<00:00, 22.45it/s, loss=3.01, batch#=875]
# Testing task 3: 219it [00:01, 158.49it/s, batch#=219]
# Testing task 0: 219it [00:01, 162.25it/s, batch#=219]
# Testing task 1: 219it [00:01, 158.12it/s, batch#=219]
# Testing task 2: 219it [00:01, 165.37it/s, batch#=219]
# Training task (ewc) 3, epoch 4: 100%|██████████| 875/875 [00:38<00:00, 22.81it/s, loss=2.6, batch#=875]
# Testing task 3: 219it [00:01, 201.52it/s, batch#=219]
# Testing task 0: 219it [00:01, 196.76it/s, batch#=219]
# Testing task 1: 219it [00:01, 208.39it/s, batch#=219]
# Testing task 2: 219it [00:01, 206.94it/s, batch#=219]
# Training task (ewc) 3, epoch 5: 100%|██████████| 875/875 [00:35<00:00, 24.64it/s, loss=2.21, batch#=875]
# Testing task 3: 219it [00:01, 201.32it/s, batch#=219]
# Testing task 0: 219it [00:01, 202.27it/s, batch#=219]
# Testing task 1: 219it [00:01, 202.30it/s, batch#=219]
# Testing task 2: 219it [00:01, 203.06it/s, batch#=219]
# Training task (ewc) 3, epoch 6: 100%|██████████| 875/875 [00:35<00:00, 24.65it/s, loss=1.96, batch#=875]
# Testing task 3: 219it [00:01, 191.40it/s, batch#=219]
# Testing task 0: 219it [00:01, 195.86it/s, batch#=219]
# Testing task 1: 219it [00:01, 200.76it/s, batch#=219]
# Testing task 2: 219it [00:01, 199.01it/s, batch#=219]
# Training task (ewc) 3, epoch 7: 100%|██████████| 875/875 [00:36<00:00, 26.33it/s, loss=1.76, batch#=875]
# Testing task 3: 219it [00:01, 207.30it/s, batch#=219]
# Testing task 0: 219it [00:01, 208.73it/s, batch#=219]
# Testing task 1: 219it [00:01, 209.18it/s, batch#=219]
# Testing task 2: 219it [00:01, 209.51it/s, batch#=219]
# Training task (ewc) 3, epoch 8: 100%|██████████| 875/875 [00:36<00:00, 24.12it/s, loss=1.66, batch#=875]
# Testing task 3: 219it [00:01, 206.74it/s, batch#=219]
# Testing task 0: 219it [00:01, 207.26it/s, batch#=219]
# Testing task 1: 219it [00:01, 204.05it/s, batch#=219]
# Testing task 2: 219it [00:01, 205.16it/s, batch#=219]
# Training task (ewc) 3, epoch 9: 100%|██████████| 875/875 [00:35<00:00, 24.10it/s, loss=1.58, batch#=875]
# Testing task 3: 219it [00:01, 205.24it/s, batch#=219]
# Testing task 0: 219it [00:01, 174.16it/s, batch#=219]
# Testing task 1: 219it [00:01, 199.34it/s, batch#=219]
# Testing task 2: 219it [00:01, 176.82it/s, batch#=219]
# Training task (ewc) 3, epoch 10: 100%|██████████| 875/875 [00:36<00:00, 24.14it/s, loss=1.48, batch#=875]
# Testing task 3: 219it [00:01, 186.98it/s, batch#=219]
# Testing task 0: 219it [00:01, 172.96it/s, batch#=219]
# Testing task 1: 219it [00:01, 193.27it/s, batch#=219]
# Testing task 2: 219it [00:01, 194.44it/s, batch#=219]
# Training task (ewc) 3, epoch 11: 100%|██████████| 875/875 [00:35<00:00, 24.51it/s, loss=1.41, batch#=875]
# Testing task 3: 219it [00:01, 195.58it/s, batch#=219]
# Testing task 0: 219it [00:01, 197.54it/s, batch#=219]
# Testing task 1: 219it [00:01, 198.75it/s, batch#=219]
# Testing task 2: 219it [00:01, 199.40it/s, batch#=219]
# Training task (ewc) 3, epoch 12: 100%|██████████| 875/875 [00:35<00:00, 24.77it/s, loss=1.36, batch#=875]
# Testing task 3: 219it [00:01, 188.76it/s, batch#=219]
# Testing task 0: 219it [00:01, 202.57it/s, batch#=219]
# Testing task 1: 219it [00:01, 201.13it/s, batch#=219]
# Testing task 2: 219it [00:01, 201.74it/s, batch#=219]
# Training task (ewc) 3, epoch 13: 100%|██████████| 875/875 [00:35<00:00, 24.80it/s, loss=1.32, batch#=875]
# Testing task 3: 219it [00:01, 191.49it/s, batch#=219]
# Testing task 0: 219it [00:01, 199.89it/s, batch#=219]
# Testing task 1: 219it [00:01, 201.73it/s, batch#=219]
# Testing task 2: 219it [00:01, 202.56it/s, batch#=219]
# Training task (ewc) 3, epoch 14: 100%|██████████| 875/875 [00:34<00:00, 24.95it/s, loss=1.26, batch#=875]
# Testing task 3: 219it [00:01, 185.81it/s, batch#=219]
# Testing task 0: 219it [00:01, 191.59it/s, batch#=219]
# Testing task 1: 219it [00:01, 189.65it/s, batch#=219]
# Testing task 2: 219it [00:01, 193.77it/s, batch#=219]
# Training task (ewc) 3, epoch 15: 100%|██████████| 875/875 [00:38<00:00, 21.06it/s, loss=1.21, batch#=875]
# Testing task 3: 219it [00:01, 182.90it/s, batch#=219]
# Testing task 0: 219it [00:01, 187.16it/s, batch#=219]
# Testing task 1: 219it [00:01, 177.06it/s, batch#=219]
# Testing task 2: 219it [00:01, 164.26it/s, batch#=219]
# Training task (ewc) 3, epoch 16: 100%|██████████| 875/875 [00:39<00:00, 21.41it/s, loss=1.17, batch#=875]
# Testing task 3: 219it [00:01, 182.14it/s, batch#=219]
# Testing task 0: 219it [00:01, 179.94it/s, batch#=219]
# Testing task 1: 219it [00:01, 180.77it/s, batch#=219]
# Testing task 2: 219it [00:01, 181.29it/s, batch#=219]
# Training task (ewc) 3, epoch 17: 100%|██████████| 875/875 [00:35<00:00, 24.42it/s, loss=1.15, batch#=875]
# Testing task 3: 219it [00:01, 197.87it/s, batch#=219]
# Testing task 0: 219it [00:01, 199.98it/s, batch#=219]
# Testing task 1: 219it [00:01, 201.14it/s, batch#=219]
# Testing task 2: 219it [00:01, 199.02it/s, batch#=219]
# Training task (ewc) 3, epoch 18: 100%|██████████| 875/875 [00:34<00:00, 25.24it/s, loss=1.1, batch#=875]
# Testing task 3: 219it [00:01, 198.54it/s, batch#=219]
# Testing task 0: 219it [00:01, 191.49it/s, batch#=219]
# Testing task 1: 219it [00:01, 195.48it/s, batch#=219]
# Testing task 2: 219it [00:01, 190.23it/s, batch#=219]
# Training task (ewc) 3, epoch 19: 100%|██████████| 875/875 [00:37<00:00, 23.40it/s, loss=1.05, batch#=875]
# Testing task 3: 219it [00:01, 173.65it/s, batch#=219]
# Testing task 0: 219it [00:01, 174.95it/s, batch#=219]
# Testing task 1: 219it [00:01, 180.07it/s, batch#=219]
# Testing task 2: 219it [00:01, 185.09it/s, batch#=219]
# Training task (ewc) 3, epoch 20: 100%|██████████| 875/875 [00:39<00:00, 22.35it/s, loss=1.02, batch#=875]
# Testing task 3: 219it [00:01, 188.24it/s, batch#=219]
# Testing task 0: 219it [00:01, 189.64it/s, batch#=219]
# Testing task 1: 219it [00:01, 185.94it/s, batch#=219]
# Testing task 2: 219it [00:01, 189.63it/s, batch#=219]
# /media/jary/DATA/Uni/tesi/codice/utils/datasetsUtils/dataset.py:53: UserWarning: No more tasks...
#   warnings.warn("No more tasks...")

# %%
print('RESULTS')
for name, r in results:
    print(name, r['metrics'])
    print()
    
for name, r in results_kaf:
    print(name, r['metrics'])
    print()
# Out:
# RESULTS
# no_cont_learning {'fwt': 0.8206547619047618, 'bwt': -0.07090476190476193, 'remembering': 0.9290952380952381, 'pbwt': 0, 'accuracy': 0.42358571428571423}
#
# ewc {'fwt': 0.8691666666666666, 'bwt': -0.0047499999999999765, 'remembering': 0.99525, 'pbwt': 0, 'accuracy': 0.4053857142857143}
#
# gem {'fwt': 0.9341904761904761, 'bwt': 0.10310714285714284, 'remembering': 1, 'pbwt': 0.10310714285714284, 'accuracy': 0.37242857142857144}
#
# kaf_no_cont_learning {'fwt': 0.8214285714285713, 'bwt': -0.0851071428571429, 'remembering': 0.9148928571428571, 'pbwt': 0, 'accuracy': 0.43389999999999995}
#
# kaf_ewc {'fwt': 0.8865714285714285, 'bwt': -0.0068571428571428394, 'remembering': 0.9931428571428571, 'pbwt': 0, 'accuracy': 0.4217857142857143}
#
# kaf_gem {'fwt': 0.9433690476190476, 'bwt': 0.061869047619047636, 'remembering': 1, 'pbwt': 0.061869047619047636, 'accuracy': 0.3966785714285714}

# %%
n_task = len(results[0][1]['tasks'])

tot_epochs = 0

for _, r in results:
    for k, v in r['tasks'].items():
        tot_epochs = max(tot_epochs, len(v['accuracy']))
      
fig, ax = plt.subplots(nrows=n_task, ncols=2, figsize=(22, 24), sharex=True, sharey=True)

for name, r in results:
    for i, task in enumerate(r['tasks'].keys()):

        com = r['tasks'][task]
        #no_ewt = metrics_no_ewt['tasks'][task]

        x = range(tot_epochs-len(com['accuracy']), tot_epochs)

        #ax = fig.add_subplot(n_task, 1, i+1, sharex=ax) 

        ax[i][0].plot(x, com['accuracy'], label=name)
        #ax.plot(x, no_ewt['accuracy'], label='online ewt')

        ax[i][0].set_xticks(range(0, tot_epochs, 5),minor=False)

        ax[i][0].set_title("Task {}".format(task))
        ax[i][0].legend(loc="lower left")
        ax[i][0].grid(True, axis='both')
        
for name, r in results_kaf:
    for i, task in enumerate(r['tasks'].keys()):

        com = r['tasks'][task]
        #no_ewt = metrics_no_ewt['tasks'][task]

        x = range(tot_epochs-len(com['accuracy']), tot_epochs)

        #ax = fig.add_subplot(n_task, 1, i+1, sharex=ax) 

        ax[i][1].plot(x, com['accuracy'], label=name)
        #ax.plot(x, no_ewt['accuracy'], label='online ewt')

        ax[i][1].set_xticks(range(0, tot_epochs, 5),minor=False)

        ax[i][1].set_title("Task {}".format(task))
        ax[i][1].legend(loc="lower left")
        ax[i][1].grid(True, axis='both')
        
fig.subplots_adjust(hspace=0.1, wspace=0.01)

# %%
n_task = len(results[0][1]['tasks'])

tot_epochs = 0

for _, r in results:
    for k, v in r['tasks'].items():
        tot_epochs = max(tot_epochs, len(v['accuracy']))
      
fig, ax = plt.subplots(nrows=n_task, ncols=1, figsize=(22, 24), sharex=True, sharey=True)

for name, r in results:
    for i, task in enumerate(r['tasks'].keys()):

        com = r['tasks'][task]
        #no_ewt = metrics_no_ewt['tasks'][task]

        x = range(tot_epochs-len(com['accuracy']), tot_epochs)

        #ax = fig.add_subplot(n_task, 1, i+1, sharex=ax) 

        ax[i][0].plot(x, com['accuracy'], label=name)
        #ax.plot(x, no_ewt['accuracy'], label='online ewt')

        ax[i][0].set_xticks(range(0, tot_epochs, 5),minor=False)

        ax[i][0].set_title("Task {}".format(task))
        ax[i][0].legend(loc="lower left")
        ax[i][0].grid(True, axis='both')
        
for name, r in results_kaf:
    for i, task in enumerate(r['tasks'].keys()):

        com = r['tasks'][task]
        #no_ewt = metrics_no_ewt['tasks'][task]

        x = range(tot_epochs-len(com['accuracy']), tot_epochs)

        #ax = fig.add_subplot(n_task, 1, i+1, sharex=ax) 

        ax[i][0].plot(x, com['accuracy'], label=name)
        #ax.plot(x, no_ewt['accuracy'], label='online ewt')

        ax[i][0].set_xticks(range(0, tot_epochs, 5),minor=False)

        ax[i][0].set_title("Task {}".format(task))
        ax[i][0].legend(loc="lower left")
        ax[i][0].grid(True, axis='both')
        
fig.subplots_adjust(hspace=0.1, wspace=0.01)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-1b71b98660dc> in <module>
#      19         #ax = fig.add_subplot(n_task, 1, i+1, sharex=ax)
#      20
# ---> 21         ax[i][0].plot(x, com['accuracy'], label=name)
#      22         #ax.plot(x, no_ewt['accuracy'], label='online ewt')
#      23
#
# TypeError: 'AxesSubplot' object does not support indexing
