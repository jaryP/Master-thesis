# %%
import sys
import os
module_path = os.path.abspath('/media/jary/DATA/Uni/tesi/codice')

if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from networks import NoKafnet, Kafnet
import utils.datasetsUtils.MINST as MINST
from utils.datasetsUtils.taskManager import SingleTargetClassificationTask, NoTask
import configs.configClasses as configClasses
from torchvision.transforms import transforms
import torch
import networks.continual_learning as continual_learning
from Trainer import Trainer
import matplotlib.pyplot as plt
from collections import defaultdict
from copy import deepcopy
import numpy as np

# %%
torch.manual_seed(0)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
np.random.seed(0)

# %%
print(torch.cuda.is_available())
print(torch.cuda.device_count())
print(torch.cuda.get_device_name(torch.cuda.current_device()))
# Out:
# True
# 1
# GeForce GTX 1050

# %%
configOnline = configClasses.OnlineLearningConfig()
configOnline.L1_REG = 0
configOnline.EPOCHS = 20
configOnline.SAVE_PATH = './models/tecnique_comparison'
configOnline.IS_CONVOLUTIONAL = False
configOnline.MODEL_NAME = ''
print(configOnline)
# Out:
# CONFIG PARAMETERS
# BATCH_SIZE: 64
# DEVICE: cuda
# EPOCHS: 20
# EWC_IMPORTANCE: 1000
# EWC_SAMPLE_SIZE: 250
# EWC_TYPE: <class 'networks.continual_learning.OnlineEWC'>
# GAMMA: 1.0
# IS_CONVOLUTIONAL: False
# ITERS: 1
# L1_REG: 0
# LOSS: cross_entropy
# LR: 0.001
# MODEL_NAME:
# OPTIMIZER: SGD
# RUN_NAME: default
# SAVE_PATH: ./models/tecnique_comparison
# USE_EWC: True
# USE_TENSORBOARD: True

# %%
dataset = MINST.PermutedMINST('../data/minst', download=True, n_permutation=4,
                        force_download=False, train_split=0.8, transform=None, target_transform=None)
dataset.load_dataset()
# Out:
# ../data/minst/download
# task #0 with train 56000 and test 14000 images (label: 0)
# task #1 with train 56000 and test 14000 images (label: 1)
# task #2 with train 56000 and test 14000 images (label: 2)
# task #3 with train 56000 and test 14000 images (label: 3)

# %%
net = NoKafnet.MLP(len(dataset.class_to_idx))

# %%
results = []
experiments = [('no_cont_learning', None), 
               ('ewc', continual_learning.OnlineEWC),
               ('gem', continual_learning.GEM)]

# %%
for name, tec in experiments:
    print(name)
    
    n = deepcopy(net)
    config = deepcopy(configOnline)
    
    config.MODEL_NAME = name

    if 'name' == 'gem':
        config.EWC_IMPORTANCE = 0.5
        
    config.EWC_TYPE = tec
    
    trainer = Trainer(n, deepcopy(dataset), config, save_modality=2)

    r = trainer.load()
    if not r:
        r = trainer.all_tasks()
    
    results.append((name, r))
    
    del trainer
    del n
# Out:
# no_cont_learning
# /media/jary/DATA/Uni/tesi/codice/Trainer.py:37: UserWarning: Ewc type is set to None
#   warnings.warn("Ewc type is set to None  ")
# ewc
# gem
# Training task (ewc) 0, epoch 1: 100%|██████████| 875/875 [00:07<00:00, 120.73it/s, loss=2.3, batch#=875]
# Testing task 0: 219it [00:00, 222.35it/s, batch#=219]
# Training task (ewc) 0, epoch 2: 100%|██████████| 875/875 [00:04<00:00, 176.90it/s, loss=2.29, batch#=875]
# Testing task 0: 219it [00:00, 227.32it/s, batch#=219]
# Training task (ewc) 0, epoch 3: 100%|██████████| 875/875 [00:04<00:00, 176.66it/s, loss=2.28, batch#=875]
# Testing task 0: 219it [00:00, 235.10it/s, batch#=219]
# Training task (ewc) 0, epoch 4: 100%|██████████| 875/875 [00:04<00:00, 177.75it/s, loss=2.27, batch#=875]
# Testing task 0: 219it [00:00, 235.60it/s, batch#=219]
# Training task (ewc) 0, epoch 5: 100%|██████████| 875/875 [00:04<00:00, 176.23it/s, loss=2.25, batch#=875]
# Testing task 0: 219it [00:00, 234.54it/s, batch#=219]
# Training task (ewc) 0, epoch 6: 100%|██████████| 875/875 [00:04<00:00, 177.19it/s, loss=2.22, batch#=875]
# Testing task 0: 219it [00:00, 240.27it/s, batch#=219]
# Training task (ewc) 0, epoch 7: 100%|██████████| 875/875 [00:04<00:00, 178.83it/s, loss=2.17, batch#=875]
# Testing task 0: 219it [00:00, 235.00it/s, batch#=219]
# Training task (ewc) 0, epoch 8: 100%|██████████| 875/875 [00:04<00:00, 177.60it/s, loss=2.09, batch#=875]
# Testing task 0: 219it [00:00, 234.24it/s, batch#=219]
# Training task (ewc) 0, epoch 9: 100%|██████████| 875/875 [00:04<00:00, 177.60it/s, loss=1.95, batch#=875]
# Testing task 0: 219it [00:00, 235.88it/s, batch#=219]
# Training task (ewc) 0, epoch 10: 100%|██████████| 875/875 [00:04<00:00, 175.94it/s, loss=1.72, batch#=875]
# Testing task 0: 219it [00:00, 228.37it/s, batch#=219]
# Training task (ewc) 0, epoch 11: 100%|██████████| 875/875 [00:04<00:00, 179.70it/s, loss=1.42, batch#=875]
# Testing task 0: 219it [00:00, 230.55it/s, batch#=219]
# Training task (ewc) 0, epoch 12: 100%|██████████| 875/875 [00:04<00:00, 177.06it/s, loss=1.15, batch#=875]
# Testing task 0: 219it [00:00, 238.21it/s, batch#=219]
# Training task (ewc) 0, epoch 13: 100%|██████████| 875/875 [00:04<00:00, 177.69it/s, loss=0.95, batch#=875]
# Testing task 0: 219it [00:00, 238.61it/s, batch#=219]
# Training task (ewc) 0, epoch 14: 100%|██████████| 875/875 [00:04<00:00, 180.45it/s, loss=0.818, batch#=875]
# Testing task 0: 219it [00:00, 238.74it/s, batch#=219]
# Training task (ewc) 0, epoch 15: 100%|██████████| 875/875 [00:04<00:00, 175.38it/s, loss=0.727, batch#=875]
# Testing task 0: 219it [00:00, 236.78it/s, batch#=219]
# Training task (ewc) 0, epoch 16: 100%|██████████| 875/875 [00:04<00:00, 184.17it/s, loss=0.662, batch#=875]
# Testing task 0: 219it [00:00, 225.38it/s, batch#=219]
# Training task (ewc) 0, epoch 17: 100%|██████████| 875/875 [00:04<00:00, 176.67it/s, loss=0.614, batch#=875]
# Testing task 0: 219it [00:00, 232.28it/s, batch#=219]
# Training task (ewc) 0, epoch 18: 100%|██████████| 875/875 [00:04<00:00, 178.57it/s, loss=0.577, batch#=875]
# Testing task 0: 219it [00:00, 240.69it/s, batch#=219]
# Training task (ewc) 0, epoch 19: 100%|██████████| 875/875 [00:04<00:00, 177.70it/s, loss=0.547, batch#=875]
# Testing task 0: 219it [00:00, 242.85it/s, batch#=219]
# Training task (ewc) 0, epoch 20: 100%|██████████| 875/875 [00:04<00:00, 175.88it/s, loss=0.522, batch#=875]
# Testing task 0: 219it [00:00, 241.46it/s, batch#=219]
# Testing task 1: 219it [00:00, 240.84it/s, batch#=219]
# Testing task 2: 219it [00:00, 234.96it/s, batch#=219]
# Testing task 3: 219it [00:00, 235.31it/s, batch#=219]
# Training task (ewc) 1, epoch 1: 100%|██████████| 875/875 [00:25<00:00, 34.42it/s, loss=1.83, batch#=875]
# Testing task 1: 219it [00:00, 222.70it/s, batch#=219]
# Testing task 0: 219it [00:00, 239.56it/s, batch#=219]
# Training task (ewc) 1, epoch 2: 100%|██████████| 875/875 [00:23<00:00, 36.65it/s, loss=1.27, batch#=875]
# Testing task 1: 219it [00:00, 222.34it/s, batch#=219]
# Testing task 0: 219it [00:00, 238.15it/s, batch#=219]
# Training task (ewc) 1, epoch 3: 100%|██████████| 875/875 [00:23<00:00, 36.62it/s, loss=1.13, batch#=875]
# Testing task 1: 219it [00:00, 222.77it/s, batch#=219]
# Testing task 0: 219it [00:00, 233.52it/s, batch#=219]
# Training task (ewc) 1, epoch 4: 100%|██████████| 875/875 [00:23<00:00, 36.63it/s, loss=1.06, batch#=875]
# Testing task 1: 219it [00:00, 223.97it/s, batch#=219]
# Testing task 0: 219it [00:00, 229.78it/s, batch#=219]
# Training task (ewc) 1, epoch 5: 100%|██████████| 875/875 [00:23<00:00, 36.93it/s, loss=1.01, batch#=875]
# Testing task 1: 219it [00:00, 224.38it/s, batch#=219]
# Testing task 0: 219it [00:00, 232.18it/s, batch#=219]
# Training task (ewc) 1, epoch 6: 100%|██████████| 875/875 [00:23<00:00, 37.39it/s, loss=0.943, batch#=875]
# Testing task 1: 219it [00:00, 222.17it/s, batch#=219]
# Testing task 0: 219it [00:00, 238.51it/s, batch#=219]
# Training task (ewc) 1, epoch 7: 100%|██████████| 875/875 [00:25<00:00, 33.85it/s, loss=0.918, batch#=875]
# Testing task 1: 219it [00:01, 181.09it/s, batch#=219]
# Testing task 0: 219it [00:00, 225.58it/s, batch#=219]
# Training task (ewc) 1, epoch 8: 100%|██████████| 875/875 [00:24<00:00, 35.12it/s, loss=0.905, batch#=875]
# Testing task 1: 219it [00:00, 225.51it/s, batch#=219]
# Testing task 0: 219it [00:01, 190.69it/s, batch#=219]
# Training task (ewc) 1, epoch 9: 100%|██████████| 875/875 [00:25<00:00, 34.56it/s, loss=0.867, batch#=875]
# Testing task 1: 219it [00:01, 215.57it/s, batch#=219]
# Testing task 0: 219it [00:00, 236.09it/s, batch#=219]
# Training task (ewc) 1, epoch 10: 100%|██████████| 875/875 [00:24<00:00, 36.31it/s, loss=0.849, batch#=875]
# Testing task 1: 219it [00:01, 188.17it/s, batch#=219]
# Testing task 0: 219it [00:01, 175.60it/s, batch#=219]
# Training task (ewc) 1, epoch 11: 100%|██████████| 875/875 [00:25<00:00, 33.98it/s, loss=0.843, batch#=875]
# Testing task 1: 219it [00:01, 188.22it/s, batch#=219]
# Testing task 0: 219it [00:01, 195.15it/s, batch#=219]
# Training task (ewc) 1, epoch 12: 100%|██████████| 875/875 [00:25<00:00, 33.53it/s, loss=0.834, batch#=875]
# Testing task 1: 219it [00:01, 225.84it/s, batch#=219]
# Testing task 0: 219it [00:01, 188.75it/s, batch#=219]
# Training task (ewc) 1, epoch 13: 100%|██████████| 875/875 [00:24<00:00, 35.13it/s, loss=0.822, batch#=875]
# Testing task 1: 219it [00:01, 187.91it/s, batch#=219]
# Testing task 0: 219it [00:01, 196.16it/s, batch#=219]
# Training task (ewc) 1, epoch 14: 100%|██████████| 875/875 [00:25<00:00, 33.96it/s, loss=0.834, batch#=875]
# Testing task 1: 219it [00:01, 198.07it/s, batch#=219]
# Testing task 0: 219it [00:01, 190.46it/s, batch#=219]
# Training task (ewc) 1, epoch 15: 100%|██████████| 875/875 [00:24<00:00, 36.31it/s, loss=0.804, batch#=875]
# Testing task 1: 219it [00:01, 222.31it/s, batch#=219]
# Testing task 0: 219it [00:00, 230.38it/s, batch#=219]
# Training task (ewc) 1, epoch 16: 100%|██████████| 875/875 [00:23<00:00, 36.89it/s, loss=0.749, batch#=875]
# Testing task 1: 219it [00:01, 217.17it/s, batch#=219]
# Testing task 0: 219it [00:01, 214.55it/s, batch#=219]
# Training task (ewc) 1, epoch 17: 100%|██████████| 875/875 [00:24<00:00, 36.02it/s, loss=0.733, batch#=875]
# Testing task 1: 219it [00:01, 205.93it/s, batch#=219]
# Testing task 0: 219it [00:00, 244.23it/s, batch#=219]
# Training task (ewc) 1, epoch 18: 100%|██████████| 875/875 [00:24<00:00, 35.69it/s, loss=0.741, batch#=875]
# Testing task 1: 219it [00:01, 175.92it/s, batch#=219]
# Testing task 0: 219it [00:01, 203.00it/s, batch#=219]
# Training task (ewc) 1, epoch 19: 100%|██████████| 875/875 [00:24<00:00, 35.41it/s, loss=0.715, batch#=875]
# Testing task 1: 219it [00:01, 195.99it/s, batch#=219]
# Testing task 0: 219it [00:01, 197.89it/s, batch#=219]
# Training task (ewc) 1, epoch 20: 100%|██████████| 875/875 [00:24<00:00, 35.79it/s, loss=0.669, batch#=875]
# Testing task 1: 219it [00:01, 181.25it/s, batch#=219]
# Testing task 0: 219it [00:01, 218.07it/s, batch#=219]
# Testing task 2: 219it [00:01, 215.76it/s, batch#=219]
# Testing task 3: 219it [00:01, 215.72it/s, batch#=219]
# Training task (ewc) 2, epoch 1: 100%|██████████| 875/875 [00:38<00:00, 22.49it/s, loss=2.89, batch#=875]
# Testing task 2: 219it [00:01, 214.66it/s, batch#=219]
# Testing task 0: 219it [00:00, 227.95it/s, batch#=219]
# Testing task 1: 219it [00:00, 237.22it/s, batch#=219]
# Training task (ewc) 2, epoch 2: 100%|██████████| 875/875 [00:38<00:00, 22.77it/s, loss=2.22, batch#=875]
# Testing task 2: 219it [00:00, 224.23it/s, batch#=219]
# Testing task 0: 219it [00:00, 234.15it/s, batch#=219]
# Testing task 1: 219it [00:00, 226.40it/s, batch#=219]
# Training task (ewc) 2, epoch 3: 100%|██████████| 875/875 [00:37<00:00, 22.30it/s, loss=1.85, batch#=875]
# Testing task 2: 219it [00:00, 231.69it/s, batch#=219]
# Testing task 0: 219it [00:00, 237.90it/s, batch#=219]
# Testing task 1: 219it [00:00, 245.65it/s, batch#=219]
# Training task (ewc) 2, epoch 4: 100%|██████████| 875/875 [00:37<00:00, 23.20it/s, loss=1.59, batch#=875]
# Testing task 2: 219it [00:00, 222.36it/s, batch#=219]
# Testing task 0: 219it [00:00, 234.96it/s, batch#=219]
# Testing task 1: 219it [00:00, 238.87it/s, batch#=219]
# Training task (ewc) 2, epoch 5: 100%|██████████| 875/875 [00:37<00:00, 23.20it/s, loss=1.43, batch#=875]
# Testing task 2: 219it [00:00, 219.37it/s, batch#=219]
# Testing task 0: 219it [00:00, 227.19it/s, batch#=219]
# Testing task 1: 219it [00:00, 233.14it/s, batch#=219]
# Training task (ewc) 2, epoch 6: 100%|██████████| 875/875 [00:39<00:00, 22.37it/s, loss=1.31, batch#=875]
# Testing task 2: 219it [00:00, 224.90it/s, batch#=219]
# Testing task 0: 219it [00:00, 236.70it/s, batch#=219]
# Testing task 1: 219it [00:00, 240.31it/s, batch#=219]
# Training task (ewc) 2, epoch 7: 100%|██████████| 875/875 [00:33<00:00, 26.32it/s, loss=1.23, batch#=875]
# Testing task 2: 219it [00:00, 261.36it/s, batch#=219]
# Testing task 0: 219it [00:00, 264.37it/s, batch#=219]
# Testing task 1: 219it [00:00, 263.98it/s, batch#=219]
# Training task (ewc) 2, epoch 8: 100%|██████████| 875/875 [00:28<00:00, 30.86it/s, loss=1.13, batch#=875]
# Testing task 2: 219it [00:00, 254.37it/s, batch#=219]
# Testing task 0: 219it [00:00, 259.14it/s, batch#=219]
# Testing task 1: 219it [00:00, 259.03it/s, batch#=219]
# Training task (ewc) 2, epoch 9: 100%|██████████| 875/875 [00:27<00:00, 31.31it/s, loss=1.09, batch#=875]
# Testing task 2: 219it [00:00, 257.23it/s, batch#=219]
# Testing task 0: 219it [00:00, 259.46it/s, batch#=219]
# Testing task 1: 219it [00:00, 259.60it/s, batch#=219]
# Training task (ewc) 2, epoch 10: 100%|██████████| 875/875 [00:27<00:00, 31.34it/s, loss=1.02, batch#=875]
# Testing task 2: 219it [00:00, 256.25it/s, batch#=219]
# Testing task 0: 219it [00:00, 259.84it/s, batch#=219]
# Testing task 1: 219it [00:00, 260.86it/s, batch#=219]
# Training task (ewc) 2, epoch 11: 100%|██████████| 875/875 [00:27<00:00, 31.70it/s, loss=0.966, batch#=875]
# Testing task 2: 219it [00:00, 251.88it/s, batch#=219]
# Testing task 0: 219it [00:00, 258.06it/s, batch#=219]
# Testing task 1: 219it [00:00, 259.13it/s, batch#=219]
# Training task (ewc) 2, epoch 12: 100%|██████████| 875/875 [00:27<00:00, 31.98it/s, loss=0.915, batch#=875]
# Testing task 2: 219it [00:00, 255.53it/s, batch#=219]
# Testing task 0: 219it [00:00, 260.20it/s, batch#=219]
# Testing task 1: 219it [00:00, 256.82it/s, batch#=219]
# Training task (ewc) 2, epoch 13: 100%|██████████| 875/875 [00:27<00:00, 31.43it/s, loss=0.871, batch#=875]
# Testing task 2: 219it [00:00, 253.92it/s, batch#=219]
# Testing task 0: 219it [00:00, 257.80it/s, batch#=219]
# Testing task 1: 219it [00:00, 259.22it/s, batch#=219]
# Training task (ewc) 2, epoch 14: 100%|██████████| 875/875 [00:28<00:00, 26.66it/s, loss=0.839, batch#=875]
# Testing task 2: 219it [00:01, 212.71it/s, batch#=219]
# Testing task 0: 219it [00:01, 212.16it/s, batch#=219]
# Testing task 1: 219it [00:00, 220.36it/s, batch#=219]
# Training task (ewc) 2, epoch 15: 100%|██████████| 875/875 [00:29<00:00, 30.17it/s, loss=0.816, batch#=875]
# Testing task 2: 219it [00:00, 248.15it/s, batch#=219]
# Testing task 0: 219it [00:00, 249.65it/s, batch#=219]
# Testing task 1: 219it [00:00, 253.60it/s, batch#=219]
# Training task (ewc) 2, epoch 16: 100%|██████████| 875/875 [00:28<00:00, 31.09it/s, loss=0.809, batch#=875]
# Testing task 2: 219it [00:00, 248.78it/s, batch#=219]
# Testing task 0: 219it [00:00, 253.08it/s, batch#=219]
# Testing task 1: 219it [00:00, 254.49it/s, batch#=219]
# Training task (ewc) 2, epoch 17: 100%|██████████| 875/875 [00:27<00:00, 31.38it/s, loss=0.806, batch#=875]
# Testing task 2: 219it [00:00, 245.54it/s, batch#=219]
# Testing task 0: 219it [00:00, 248.10it/s, batch#=219]
# Testing task 1: 219it [00:00, 253.42it/s, batch#=219]
# Training task (ewc) 2, epoch 18: 100%|██████████| 875/875 [00:28<00:00, 27.34it/s, loss=0.76, batch#=875]
# Testing task 2: 219it [00:00, 226.26it/s, batch#=219]
# Testing task 0: 219it [00:01, 203.34it/s, batch#=219]
# Testing task 1: 219it [00:00, 225.13it/s, batch#=219]
# Training task (ewc) 2, epoch 19: 100%|██████████| 875/875 [00:29<00:00, 30.23it/s, loss=0.705, batch#=875]
# Testing task 2: 219it [00:00, 236.49it/s, batch#=219]
# Testing task 0: 219it [00:00, 225.98it/s, batch#=219]
# Testing task 1: 219it [00:00, 233.49it/s, batch#=219]
# Training task (ewc) 2, epoch 20: 100%|██████████| 875/875 [00:29<00:00, 29.68it/s, loss=0.718, batch#=875]
# Testing task 2: 219it [00:00, 236.45it/s, batch#=219]
# Testing task 0: 219it [00:00, 230.21it/s, batch#=219]
# Testing task 1: 219it [00:00, 239.06it/s, batch#=219]
# Testing task 3: 219it [00:00, 243.08it/s, batch#=219]
# Training task (ewc) 3, epoch 1: 100%|██████████| 875/875 [00:39<00:00, 22.26it/s, loss=3.6, batch#=875]
# Testing task 3: 219it [00:00, 247.89it/s, batch#=219]
# Testing task 0: 219it [00:00, 243.94it/s, batch#=219]
# Testing task 1: 219it [00:00, 249.69it/s, batch#=219]
# Testing task 2: 219it [00:00, 248.59it/s, batch#=219]
# Training task (ewc) 3, epoch 2: 100%|██████████| 875/875 [00:39<00:00, 22.33it/s, loss=2.79, batch#=875]
# Testing task 3: 219it [00:00, 243.59it/s, batch#=219]
# Testing task 0: 219it [00:00, 243.98it/s, batch#=219]
# Testing task 1: 219it [00:00, 245.75it/s, batch#=219]
# Testing task 2: 219it [00:00, 244.43it/s, batch#=219]
# Training task (ewc) 3, epoch 3: 100%|██████████| 875/875 [00:36<00:00, 23.78it/s, loss=2.32, batch#=875]
# Testing task 3: 219it [00:00, 243.19it/s, batch#=219]
# Testing task 0: 219it [00:00, 245.46it/s, batch#=219]
# Testing task 1: 219it [00:00, 241.16it/s, batch#=219]
# Testing task 2: 219it [00:00, 240.67it/s, batch#=219]
# Training task (ewc) 3, epoch 4: 100%|██████████| 875/875 [00:36<00:00, 23.68it/s, loss=2.03, batch#=875]
# Testing task 3: 219it [00:00, 239.13it/s, batch#=219]
# Testing task 0: 219it [00:00, 248.65it/s, batch#=219]
# Testing task 1: 219it [00:00, 248.72it/s, batch#=219]
# Testing task 2: 219it [00:00, 249.07it/s, batch#=219]
# Training task (ewc) 3, epoch 5: 100%|██████████| 875/875 [00:37<00:00, 23.82it/s, loss=1.8, batch#=875]
# Testing task 3: 219it [00:00, 246.41it/s, batch#=219]
# Testing task 0: 219it [00:00, 249.57it/s, batch#=219]
# Testing task 1: 219it [00:00, 246.02it/s, batch#=219]
# Testing task 2: 219it [00:00, 246.95it/s, batch#=219]
# Training task (ewc) 3, epoch 6: 100%|██████████| 875/875 [00:38<00:00, 23.02it/s, loss=1.63, batch#=875]
# Testing task 3: 219it [00:00, 242.53it/s, batch#=219]
# Testing task 0: 219it [00:00, 244.05it/s, batch#=219]
# Testing task 1: 219it [00:00, 247.89it/s, batch#=219]
# Testing task 2: 219it [00:00, 245.76it/s, batch#=219]
# Training task (ewc) 3, epoch 7: 100%|██████████| 875/875 [00:39<00:00, 22.09it/s, loss=1.47, batch#=875]
# Testing task 3: 219it [00:01, 216.37it/s, batch#=219]
# Testing task 0: 219it [00:01, 217.23it/s, batch#=219]
# Testing task 1: 219it [00:01, 217.21it/s, batch#=219]
# Testing task 2: 219it [00:00, 231.01it/s, batch#=219]
# Training task (ewc) 3, epoch 8: 100%|██████████| 875/875 [00:37<00:00, 22.26it/s, loss=1.39, batch#=875]
# Testing task 3: 219it [00:01, 217.74it/s, batch#=219]
# Testing task 0: 219it [00:01, 212.58it/s, batch#=219]
# Testing task 1: 219it [00:01, 212.93it/s, batch#=219]
# Testing task 2: 219it [00:00, 221.83it/s, batch#=219]
# Training task (ewc) 3, epoch 9: 100%|██████████| 875/875 [00:37<00:00, 24.94it/s, loss=1.29, batch#=875]
# Testing task 3: 219it [00:00, 248.28it/s, batch#=219]
# Testing task 0: 219it [00:00, 246.34it/s, batch#=219]
# Testing task 1: 219it [00:00, 243.87it/s, batch#=219]
# Testing task 2: 219it [00:00, 246.79it/s, batch#=219]
# Training task (ewc) 3, epoch 10: 100%|██████████| 875/875 [00:37<00:00, 23.33it/s, loss=1.21, batch#=875]
# Testing task 3: 219it [00:00, 241.53it/s, batch#=219]
# Testing task 0: 219it [00:00, 245.55it/s, batch#=219]
# Testing task 1: 219it [00:00, 246.13it/s, batch#=219]
# Testing task 2: 219it [00:00, 246.67it/s, batch#=219]
# Training task (ewc) 3, epoch 11: 100%|██████████| 875/875 [00:37<00:00, 23.18it/s, loss=1.14, batch#=875]
# Testing task 3: 219it [00:00, 249.39it/s, batch#=219]
# Testing task 0: 219it [00:00, 249.22it/s, batch#=219]
# Testing task 1: 219it [00:00, 243.76it/s, batch#=219]
# Testing task 2: 219it [00:00, 246.42it/s, batch#=219]
# Training task (ewc) 3, epoch 12: 100%|██████████| 875/875 [00:37<00:00, 23.57it/s, loss=1.08, batch#=875]
# Testing task 3: 219it [00:00, 245.36it/s, batch#=219]
# Testing task 0: 219it [00:00, 247.58it/s, batch#=219]
# Testing task 1: 219it [00:00, 244.71it/s, batch#=219]
# Testing task 2: 219it [00:00, 246.67it/s, batch#=219]
# Training task (ewc) 3, epoch 13: 100%|██████████| 875/875 [00:37<00:00, 23.49it/s, loss=1.03, batch#=875]
# Testing task 3: 219it [00:00, 247.66it/s, batch#=219]
# Testing task 0: 219it [00:00, 248.25it/s, batch#=219]
# Testing task 1: 219it [00:00, 246.05it/s, batch#=219]
# Testing task 2: 219it [00:00, 248.62it/s, batch#=219]
# Training task (ewc) 3, epoch 14: 100%|██████████| 875/875 [00:37<00:00, 23.70it/s, loss=0.978, batch#=875]
# Testing task 3: 219it [00:00, 250.10it/s, batch#=219]
# Testing task 0: 219it [00:00, 245.03it/s, batch#=219]
# Testing task 1: 219it [00:00, 239.16it/s, batch#=219]
# Testing task 2: 219it [00:00, 241.67it/s, batch#=219]
# Training task (ewc) 3, epoch 15: 100%|██████████| 875/875 [00:37<00:00, 22.93it/s, loss=0.95, batch#=875]
# Testing task 3: 219it [00:00, 239.22it/s, batch#=219]
# Testing task 0: 219it [00:00, 246.49it/s, batch#=219]
# Testing task 1: 219it [00:00, 245.27it/s, batch#=219]
# Testing task 2: 219it [00:00, 245.31it/s, batch#=219]
# Training task (ewc) 3, epoch 16: 100%|██████████| 875/875 [00:37<00:00, 23.35it/s, loss=0.92, batch#=875]
# Testing task 3: 219it [00:00, 241.00it/s, batch#=219]
# Testing task 0: 219it [00:00, 242.31it/s, batch#=219]
# Testing task 1: 219it [00:00, 242.27it/s, batch#=219]
# Testing task 2: 219it [00:00, 241.28it/s, batch#=219]
# Training task (ewc) 3, epoch 17: 100%|██████████| 875/875 [00:37<00:00, 22.22it/s, loss=0.881, batch#=875]
# Testing task 3: 219it [00:00, 240.52it/s, batch#=219]
# Testing task 0: 219it [00:00, 239.77it/s, batch#=219]
# Testing task 1: 219it [00:00, 242.69it/s, batch#=219]
# Testing task 2: 219it [00:00, 245.72it/s, batch#=219]
# Training task (ewc) 3, epoch 18: 100%|██████████| 875/875 [00:37<00:00, 23.24it/s, loss=0.837, batch#=875]
# Testing task 3: 219it [00:00, 246.54it/s, batch#=219]
# Testing task 0: 219it [00:00, 247.91it/s, batch#=219]
# Testing task 1: 219it [00:00, 249.27it/s, batch#=219]
# Testing task 2: 219it [00:00, 247.57it/s, batch#=219]
# Training task (ewc) 3, epoch 19: 100%|██████████| 875/875 [00:37<00:00, 23.16it/s, loss=0.807, batch#=875]
# Testing task 3: 219it [00:00, 241.41it/s, batch#=219]
# Testing task 0: 219it [00:00, 254.27it/s, batch#=219]
# Testing task 1: 219it [00:00, 243.24it/s, batch#=219]
# Testing task 2: 219it [00:00, 242.17it/s, batch#=219]
# Training task (ewc) 3, epoch 20: 100%|██████████| 875/875 [00:37<00:00, 25.07it/s, loss=0.782, batch#=875]
# Testing task 3: 219it [00:00, 249.88it/s, batch#=219]
# Testing task 0: 219it [00:00, 248.03it/s, batch#=219]
# Testing task 1: 219it [00:00, 245.98it/s, batch#=219]
# Testing task 2: 219it [00:00, 250.01it/s, batch#=219]
# /media/jary/DATA/Uni/tesi/codice/utils/datasetsUtils/dataset.py:53: UserWarning: No more tasks...
#   warnings.warn("No more tasks...")

# %%
print('RESULTS')
for name, r in results:
    print(name, r['metrics'])
    print()
# Out:
# RESULTS
# no_cont_learning {'fwt': 0.8425952380952381, 'bwt': -0.04901190476190478, 'remembering': 0.9509880952380952, 'pbwt': 0, 'accuracy': 0.4300428571428572}
#
# ewc {'fwt': 0.8633452380952381, 'bwt': -0.010559523809523816, 'remembering': 0.9894404761904761, 'pbwt': 0, 'accuracy': 0.41740714285714287}
#
# gem {'fwt': 0.9328214285714287, 'bwt': 0.08947619047619045, 'remembering': 1, 'pbwt': 0.08947619047619045, 'accuracy': 0.3812142857142858}

# %%
n_task = len(results[0][1]['tasks'])

tot_epochs = 0

for _, r in results:
    for k, v in r['tasks'].items():
        tot_epochs = max(tot_epochs, len(v['accuracy']))
      
fig, ax = plt.subplots(nrows=n_task, ncols=1, figsize=(22, 24), sharex=True, sharey=True)

for name, r in results:
    for i, task in enumerate(r['tasks'].keys()):

        com = r['tasks'][task]
        #no_ewt = metrics_no_ewt['tasks'][task]

        x = range(tot_epochs-len(com['accuracy']), tot_epochs)

        #ax = fig.add_subplot(n_task, 1, i+1, sharex=ax) 

        ax[i].plot(x, com['accuracy'], label=name)
        #ax.plot(x, no_ewt['accuracy'], label='online ewt')

        ax[i].set_xticks(range(0, tot_epochs, 5),minor=False)

        ax[i].set_title("Task {}".format(task))
        ax[i].legend(loc="lower left")
        ax[i].grid(True, axis='both')

        
fig.subplots_adjust(hspace=0.1, wspace=0.01)

# %%
from mpl_toolkits.mplot3d import Axes3D

for name, tec in experiments:

    current_w = {n:p.cpu() for n, p in net.named_parameters() if p.requires_grad}

    x = np.arange(4)
    y = np.arange(len(current_w))
    
    xx, yy = np.meshgrid(x, y)
    z = np.zeros(shape=(len(x), len(y)))
    
    fig = plt.figure(figsize=(22, 22))
    ax = fig.add_subplot(111, projection='3d')
    
    x_labels = []
    
    for i in x:

        if i == 0:
            x_labels.append('0')
            
        else:
            x_labels.append('{}->{}'.format(i-1, i))
            
        n = deepcopy(net)
        config = deepcopy(configOnline)

        config.MODEL_NAME = name

        if 'name' == 'gem':
            config.EWC_IMPORTANCE = 0.5

        config.EWC_TYPE = tec

        trainer = Trainer(n, deepcopy(dataset), config, save_modality=2)

        r = trainer.load(i)
        
        diff = {n: torch.dist(p.cpu(), current_w[n]) for n, p in trainer.model.named_parameters() if p.requires_grad }
        current_w = {n: p.cpu() for n, p in trainer.model.named_parameters() if p.requires_grad }
        
        for j, (_, d) in enumerate(diff.items()):
            z[i, j] = d
    

    z_n = z.flatten()

    ax.view_init(45, 45)
    
    ax.bar3d(xx.flatten(),
          yy.flatten(),
          np.zeros(len(z_n)),
          0.2, 0.5, z_n )
    
    ax.set_xticks(x)
    ax.set_xticklabels(x_labels)
    
    ax.set_yticks(y)
    ax.set_yticklabels(list(diff.keys()), fontdict={'fontsize':12})
    
    ax.text(3.5, 0, 2, name.upper(), color='black',  fontsize='xx-large', 
        bbox=dict(facecolor='white', edgecolor='black'))
    
    plt.show()
# Out:
# no_cont_learning
# ewc
# gem
